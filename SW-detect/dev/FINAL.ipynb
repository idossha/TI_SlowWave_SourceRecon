# %%
#Make sure you have eeglabio for saving the Epochs
#pip install eeglabio


# Housekeeping imports
import os
import mne
from mne.io import RawArray
import numpy as np
import pandas as pd
import yasa
import matplotlib.pyplot as plt  # Make sure to import pyplot as plt for plotting
import statsmodels.api as sm
import ipywidgets as widgets  # Renamed for clarity
import scipy
import seaborn as sns

# Activate interactive figures with %matplotlib qt (useful in Jupyter environments)
# %matplotlib qt

# %%
fname = '/Users/idohaber/Desktop/101_test/Strength_101_forICA_wcomps_rmcomps.set'
raw = mne.io.read_raw_eeglab(fname, preload=True);

# HOUSEKEEPING: 
# 1. Make sure number and type of events make sense
# 2. Look at sensor coverage 

print(raw.annotations)# Get all unique annotation types
unique_annotations = set(raw.annotations.description)
print("Unique annotation types:", unique_annotations)
# Count the number of 'stim start' and 'stim end' annotations
stim_start_count = sum(raw.annotations.description == 'stim start')
stim_end_count = sum(raw.annotations.description == 'stim end')

print(f"Number of 'stim start' events: {stim_start_count}")
print(f"Number of 'stim end' events: {stim_end_count}")
raw.plot_sensors();
# Out:
# Reading /Users/idohaber/Desktop/101_test/Strength_101_forICA_wcomps_rmcomps.fdt
# Reading 0 ... 6496921  =      0.000 ... 12993.842 secs...
# /var/folders/0y/xvbtt0c135x04tpfn8c89v300000gn/T/ipykernel_6411/2007490884.py:2: RuntimeWarning: Limited 6 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_eeglab(fname, preload=True);
# /var/folders/0y/xvbtt0c135x04tpfn8c89v300000gn/T/ipykernel_6411/2007490884.py:2: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(fname, preload=True);
# <Annotations | 1368 segments: SE__ (18), SS__ (19), Sleep Stage (1216), ...>
# Unique annotation types: {'boundary', 'stim end', 'SE__', 'stim start', 'Sleep Stage', 'SS__'}
# Number of 'stim start' events: 22
# Number of 'stim end' events: 24

# %%
# prepare the data for processing
data = raw.get_data(units="uV") 
raw.filter(0.5, 4, fir_design='firwin', h_trans_bandwidth=0.2, l_trans_bandwidth=0.2)
raw.resample(100)
sf = raw.info['sfreq']
print(data.shape , sf)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 4 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.20 Hz (-6 dB cutoff frequency: 0.40 Hz)
# - Upper passband edge: 4.00 Hz
# - Upper transition bandwidth: 0.20 Hz (-6 dB cutoff frequency: 4.10 Hz)
# - Filter length: 8251 samples (16.502 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:   20.2s
# (198, 6496922) 100.0

# %%
# Create annotations DataFrame
annotations_df = pd.DataFrame({
    "Onset": raw.annotations.onset,
    "Duration": raw.annotations.duration,
    "Description": raw.annotations.description,
})

# Filter for only 'stim start' and 'stim end' events
stim_events = annotations_df[annotations_df["Description"].isin(["stim start", "stim end"])].reset_index(drop=True)

# Extract onset times for 'stim start' and 'stim end'
stim_start_times = stim_events[stim_events["Description"] == 'stim start']["Onset"].values
stim_end_times = stim_events[stim_events["Description"] == 'stim end']["Onset"].values

# %%
# Initialize variables
cleaned_events = []
expected_event = 'stim start'  # The sequence should start with 'stim start'
min_duration = 170  # Minimum acceptable duration in seconds
max_duration = 220  # Maximum acceptable duration in seconds
i = 0  # Index counter

# List to store information about omitted events
omitted_events = []

# Loop through the stim_events DataFrame
while i < len(stim_events):
    current_event = stim_events.iloc[i]
    if current_event["Description"] == expected_event:
        if expected_event == 'stim start':
            # Tentatively add 'stim start'
            stim_start_event = current_event
            expected_event = 'stim end'
        elif expected_event == 'stim end':
            # Check the time difference between 'stim end' and 'stim start'
            stim_end_event = current_event
            time_diff = stim_end_event["Onset"] - stim_start_event["Onset"]
            if min_duration <= time_diff <= max_duration:
                # Duration is acceptable; add both events to cleaned_events
                cleaned_events.append(stim_start_event)
                cleaned_events.append(stim_end_event)
                expected_event = 'stim start'  # Reset expected event
            else:
                # Duration is not acceptable; discard both events
                omitted_events.append({
                    'stim_start_index': stim_start_event.name,
                    'stim_start_onset': stim_start_event["Onset"],
                    'stim_end_index': stim_end_event.name,
                    'stim_end_onset': stim_end_event["Onset"],
                    'reason': f'Invalid duration ({time_diff:.2f}s)'
                })
                expected_event = 'stim start'  # Reset expected event
        i += 1  # Move to the next event
    else:
        # Event does not match expected; discard and move to the next
        omitted_events.append({
            'event_index': current_event.name,
            'event_onset': current_event["Onset"],
            'event_description': current_event["Description"],
            'reason': f"Unexpected event '{current_event['Description']}'"
        })
        i += 1  # Move to the next event
        expected_event = 'stim start'  # Reset expected event in case of mismatch

# Convert cleaned_events to DataFrame
cleaned_events_df = pd.DataFrame(cleaned_events).reset_index(drop=True)

# Convert omitted events to DataFrame
omitted_events_df = pd.DataFrame(omitted_events)

# Verify the counts
stim_start_count = (cleaned_events_df["Description"] == 'stim start').sum()
stim_end_count = (cleaned_events_df["Description"] == 'stim end').sum()

print(f"\nTotal 'stim start' events: {stim_start_count}")
print(f"Total 'stim end' events: {stim_end_count}")

# Check if we have 20 starts and ends
if stim_start_count == 20 and stim_end_count == 20:
    print("Successfully cleaned data to have 20 'stim start' and 20 'stim end' events.")
else:
    print("Warning: The number of 'stim start' and 'stim end' events does not equal 20.")

# Print omitted events with timepoints
print("\nOmitted Events with Timepoints:")
print(omitted_events_df)

# If you prefer a more readable format
print("\nDetailed Omitted Events:")
for idx, row in omitted_events_df.iterrows():
    if 'stim_start_index' in row:
        print(f"Discarded 'stim start' at index {row['stim_start_index']} (Onset: {row['stim_start_onset']:.2f}s) and "
              f"'stim end' at index {row['stim_end_index']} (Onset: {row['stim_end_onset']:.2f}s) - {row['reason']}")
    else:
        print(f"Skipped event at index {row['event_index']} (Onset: {row['event_onset']:.2f}s, "
              f"Description: '{row['event_description']}') - {row['reason']}")
# Out:
# Total 'stim start' events: 18
# Total 'stim end' events: 18
# Warning: The number of 'stim start' and 'stim end' events does not equal 20.
#
# Omitted Events with Timepoints:
#    event_index  event_onset event_description                         reason
# 0           20     8090.000          stim end    Unexpected event 'stim end'
# 1           21     8090.000          stim end    Unexpected event 'stim end'
# 2           28    10130.596          stim end    Unexpected event 'stim end'
# 3           30    10297.116        stim start  Unexpected event 'stim start'
# 4           31    10413.884          stim end    Unexpected event 'stim end'
# 5           36    11401.568          stim end    Unexpected event 'stim end'
# 6           38    11581.140        stim start  Unexpected event 'stim start'
# 7           39    11797.248          stim end    Unexpected event 'stim end'
#
# Detailed Omitted Events:
# Skipped event at index 20 (Onset: 8090.00s, Description: 'stim end') - Unexpected event 'stim end'
# Skipped event at index 21 (Onset: 8090.00s, Description: 'stim end') - Unexpected event 'stim end'
# Skipped event at index 28 (Onset: 10130.60s, Description: 'stim end') - Unexpected event 'stim end'
# Skipped event at index 30 (Onset: 10297.12s, Description: 'stim start') - Unexpected event 'stim start'
# Skipped event at index 31 (Onset: 10413.88s, Description: 'stim end') - Unexpected event 'stim end'
# Skipped event at index 36 (Onset: 11401.57s, Description: 'stim end') - Unexpected event 'stim end'
# Skipped event at index 38 (Onset: 11581.14s, Description: 'stim start') - Unexpected event 'stim start'
# Skipped event at index 39 (Onset: 11797.25s, Description: 'stim end') - Unexpected event 'stim end'

# %%
# Calculate durations between 'stim start' and 'stim end' in the original data
durations = []
i = 0
while i < len(stim_events) - 1:
    if stim_events.iloc[i]["Description"] == 'stim start' and stim_events.iloc[i+1]["Description"] == 'stim end':
        duration = stim_events.iloc[i+1]["Onset"] - stim_events.iloc[i]["Onset"]
        durations.append(duration)
        i += 2  # Skip to the next pair
    else:
        i += 1  # Move to the next event

# Plot the durations
plt.figure(figsize=(10, 5))
plt.plot(durations, marker='o')
plt.axhline(y=170, color='r', linestyle='--', label='Min Duration (170s)')
plt.axhline(y=220, color='r', linestyle='--', label='Max Duration (220s)')
plt.xlabel('Stim Pair Index')
plt.ylabel('Duration (s)')
plt.title('Durations Between "stim start" and "stim end" Events')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Ensure that cleaned_events_df is sorted by onset time and reset index
cleaned_events_df = cleaned_events_df.sort_values(by='Onset').reset_index(drop=True)

# --- First Pass: Create Epochs and Identify Overlaps ---

print("Creating epochs and identifying overlaps...\n")

# Initialize lists for epochs
pre_stim_epochs = []
stim_epochs = []
post_stim_epochs = []

# Protocol counter
protocol_number = 1

# Previous protocol's post-stim epoch
prev_post_stim_end = 0

# List to keep track of overlaps
overlaps = []

# Loop through the cleaned events to define epochs
for i in range(0, len(cleaned_events_df), 2):
    if i + 1 < len(cleaned_events_df):  # Ensure i+1 is within bounds
        stim_start_event = cleaned_events_df.iloc[i]
        stim_end_event = cleaned_events_df.iloc[i + 1]

        # Extract onset times in seconds
        stim_start = stim_start_event["Onset"]
        stim_end = stim_end_event["Onset"]
        stim_duration = stim_end - stim_start

        # Define initial pre-stim, stim, and post-stim epochs
        pre_stim_start = stim_start - stim_duration
        pre_stim_end = stim_start

        stim_epoch_start = stim_start
        stim_epoch_end = stim_end

        post_stim_start = stim_end
        post_stim_end = stim_end + stim_duration

        # Check for overlap with the previous protocol's post-stim epoch
        overlap_amount = prev_post_stim_end - pre_stim_start
        if overlap_amount > 0:
            # Calculate half of the overlap amount
            half_overlap = overlap_amount / 2

            # Adjust the previous protocol's post-stim epoch
            if len(post_stim_epochs) > 0:
                prev_protocol = protocol_number - 1
                prev_post_stim = post_stim_epochs[-1]
                adjusted_prev_post_stim_end = prev_post_stim[1] - half_overlap
                if adjusted_prev_post_stim_end < prev_post_stim[0]:
                    print(f"Warning: Negative duration for post-stim epoch of Protocol {prev_protocol}. Setting duration to zero.")
                    adjusted_prev_post_stim_end = prev_post_stim[0]
                post_stim_epochs[-1] = (prev_post_stim[0], adjusted_prev_post_stim_end, prev_post_stim[2])

                print(f"Overlap detected between Protocol {prev_protocol} and Protocol {protocol_number}:")
                print(f"  Adjusting Post-Stim End Time of Protocol {prev_protocol} by {-half_overlap:.2f}s")
                print(f"  New Post-Stim End Time of Protocol {prev_protocol}: {adjusted_prev_post_stim_end:.2f}s")

            # Adjust the current protocol's pre-stim epoch
            adjusted_pre_stim_start = pre_stim_start + half_overlap
            if adjusted_pre_stim_start > pre_stim_end:
                print(f"Warning: Negative duration for pre-stim epoch of Protocol {protocol_number}. Setting duration to zero.")
                adjusted_pre_stim_start = pre_stim_end
            pre_stim_start = adjusted_pre_stim_start

            print(f"  Adjusting Pre-Stim Start Time of Protocol {protocol_number} by {half_overlap:.2f}s")
            print(f"  New Pre-Stim Start Time of Protocol {protocol_number}: {pre_stim_start:.2f}s\n")

            # Record the overlap details
            overlaps.append({
                'protocols': (protocol_number - 1, protocol_number),
                'overlap_amount': overlap_amount,
                'adjusted_prev_post_stim_end': adjusted_prev_post_stim_end,
                'adjusted_pre_stim_start': pre_stim_start
            })
        else:
            print(f"No overlap detected before Protocol {protocol_number}.\n")

        # Update prev_post_stim_end to the end of the current post-stim epoch (after adjustment)
        prev_post_stim_end = post_stim_end

        # Append epochs with protocol number
        pre_stim_epochs.append((pre_stim_start, pre_stim_end, protocol_number))
        stim_epochs.append((stim_epoch_start, stim_epoch_end, protocol_number))
        post_stim_epochs.append((post_stim_start, post_stim_end, protocol_number))

        protocol_number += 1

print("\nEpoch creation and overlap adjustment complete.\n")

# --- Plotting the epochs with overlaps highlighted ---

import matplotlib.pyplot as plt

print("Plotting epochs with overlaps highlighted...\n")

# First Plot: Original epochs (before adjustment)
plt.figure(figsize=(15, 4))

# Plot pre-stim epochs as shaded regions
for (start, end, protocol) in pre_stim_epochs:
    plt.axvspan(start, end, color='blue', alpha=0.3, label='Pre-Stim')

# Plot stim epochs as shaded regions and add protocol numbers
for i, (start, end, protocol) in enumerate(stim_epochs):
    plt.axvspan(start, end, color='orange', alpha=0.3, label='Stim')
    # Add protocol number
    plt.text((start + end) / 2, 0.5, f'P{protocol}', color='black', fontsize=9, ha='center', va='bottom')

# Plot post-stim epochs as shaded regions
for (start, end, protocol) in post_stim_epochs:
    plt.axvspan(start, end, color='green', alpha=0.3, label='Post-Stim')

# Plot overlaps
for overlap in overlaps:
    overlap_start = pre_stim_epochs[overlap['protocols'][1] - 1][0] - (overlap['overlap_amount'] / 2)
    overlap_end = pre_stim_epochs[overlap['protocols'][1] - 1][0] + (overlap['overlap_amount'] / 2)
    plt.axvspan(overlap_start, overlap_end, color='red', alpha=0.5, label='Overlap')

# Set labels and title
plt.xlabel('Time (s)')
plt.yticks([])  # Hide y-axis ticks since it's unitless
plt.title('Stimulation Protocols with Overlaps')

# To prevent duplicate labels in the legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper right')

plt.grid(True)
plt.tight_layout()
plt.show()

# --- Second Plot: Epochs after trimming both pre-stim and post-stim epochs ---

print("Plotting epochs after adjusting to remove overlaps...\n")

# Print statements for adjusted epochs
print("Adjusted Epochs Durations:")
for idx, ((pre_start, pre_end, protocol), (post_start, post_end, _)) in enumerate(zip(pre_stim_epochs, post_stim_epochs)):
    pre_duration = pre_end - pre_start
    post_duration = post_end - post_start
    print(f"  Protocol {protocol}: Pre-Stim Duration = {pre_duration:.2f}s, Post-Stim Duration = {post_duration:.2f}s")

# Plotting adjusted epochs
plt.figure(figsize=(15, 4))

# Plot adjusted pre-stim epochs
for (start, end, protocol) in pre_stim_epochs:
    plt.axvspan(start, end, color='cyan', alpha=0.3, label='Pre-Stim Adjusted')

# Plot stim epochs and add protocol numbers
for i, (start, end, protocol) in enumerate(stim_epochs):
    plt.axvspan(start, end, color='orange', alpha=0.3, label='Stim')
    # Add protocol number
    plt.text((start + end) / 2, 0.5, f'P{protocol}', color='black', fontsize=9, ha='center', va='bottom')

# Plot adjusted post-stim epochs
for (start, end, protocol) in post_stim_epochs:
    plt.axvspan(start, end, color='lime', alpha=0.3, label='Post-Stim Adjusted')

# Set labels and title
plt.xlabel('Time (s)')
plt.yticks([])  # Hide y-axis ticks since it's unitless
plt.title('Stimulation Protocols After Adjusting Epochs')

# To prevent duplicate labels in the legend
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper right')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Creating epochs and identifying overlaps...
#
# No overlap detected before Protocol 1.
#
# No overlap detected before Protocol 2.
#
# No overlap detected before Protocol 3.
#
# No overlap detected before Protocol 4.
#
# No overlap detected before Protocol 5.
#
# Overlap detected between Protocol 5 and Protocol 6:
#   Adjusting Post-Stim End Time of Protocol 5 by -11.10s
#   New Post-Stim End Time of Protocol 5: 3847.28s
#   Adjusting Pre-Stim Start Time of Protocol 6 by 11.10s
#   New Pre-Stim Start Time of Protocol 6: 3847.28s
#
# No overlap detected before Protocol 7.
#
# No overlap detected before Protocol 8.
#
# No overlap detected before Protocol 9.
#
# No overlap detected before Protocol 10.
#
# No overlap detected before Protocol 11.
#
# Overlap detected between Protocol 11 and Protocol 12:
#   Adjusting Post-Stim End Time of Protocol 11 by -92.54s
#   New Post-Stim End Time of Protocol 11: 8769.47s
#   Adjusting Pre-Stim Start Time of Protocol 12 by 92.54s
#   New Pre-Stim Start Time of Protocol 12: 8769.47s
#
# No overlap detected before Protocol 13.
#
# No overlap detected before Protocol 14.
#
# Overlap detected between Protocol 14 and Protocol 15:
#   Adjusting Post-Stim End Time of Protocol 14 by -120.07s
#   New Post-Stim End Time of Protocol 14: 10920.42s
#   Adjusting Pre-Stim Start Time of Protocol 15 by 120.07s
#   New Pre-Stim Start Time of Protocol 15: 10920.42s
#
# No overlap detected before Protocol 16.
#
# Overlap detected between Protocol 16 and Protocol 17:
#   Adjusting Post-Stim End Time of Protocol 16 by -128.27s
#   New Post-Stim End Time of Protocol 16: 12266.16s
#   Adjusting Pre-Stim Start Time of Protocol 17 by 128.27s
#   New Pre-Stim Start Time of Protocol 17: 12266.16s
#
# Overlap detected between Protocol 17 and Protocol 18:
#   Adjusting Post-Stim End Time of Protocol 17 by -111.89s
#   New Post-Stim End Time of Protocol 17: 12674.38s
#   Adjusting Pre-Stim Start Time of Protocol 18 by 111.89s
#   New Pre-Stim Start Time of Protocol 18: 12674.38s
#
#
# Epoch creation and overlap adjustment complete.
#
# Plotting epochs with overlaps highlighted...
#
# Plotting epochs after adjusting to remove overlaps...
#
# Adjusted Epochs Durations:
#   Protocol 1: Pre-Stim Duration = 216.07s, Post-Stim Duration = 216.07s
#   Protocol 2: Pre-Stim Duration = 205.89s, Post-Stim Duration = 205.89s
#   Protocol 3: Pre-Stim Duration = 216.07s, Post-Stim Duration = 216.07s
#   Protocol 4: Pre-Stim Duration = 216.08s, Post-Stim Duration = 216.08s
#   Protocol 5: Pre-Stim Duration = 210.63s, Post-Stim Duration = 199.53s
#   Protocol 6: Pre-Stim Duration = 167.28s, Post-Stim Duration = 178.38s
#   Protocol 7: Pre-Stim Duration = 214.25s, Post-Stim Duration = 214.25s
#   Protocol 8: Pre-Stim Duration = 216.09s, Post-Stim Duration = 216.09s
#   Protocol 9: Pre-Stim Duration = 216.08s, Post-Stim Duration = 216.08s
#   Protocol 10: Pre-Stim Duration = 186.07s, Post-Stim Duration = 186.07s
#   Protocol 11: Pre-Stim Duration = 199.34s, Post-Stim Duration = 106.80s
#   Protocol 12: Pre-Stim Duration = 123.57s, Post-Stim Duration = 216.11s
#   Protocol 13: Pre-Stim Duration = 209.61s, Post-Stim Duration = 209.61s
#   Protocol 14: Pre-Stim Duration = 214.68s, Post-Stim Duration = 94.61s
#   Protocol 15: Pre-Stim Duration = 92.92s, Post-Stim Duration = 212.99s
#   Protocol 16: Pre-Stim Duration = 211.33s, Post-Stim Duration = 83.06s
#   Protocol 17: Pre-Stim Duration = 87.86s, Post-Stim Duration = 104.24s
#   Protocol 18: Pre-Stim Duration = 69.65s, Post-Stim Duration = 181.54s

# %%
#sw = yasa.sw_detect(raw, hypno=hypno_up, include=(2, 3))
sw = yasa.sw_detect(raw, freq_sw=(0.5, 4), verbose=False, coupling=False)
df = sw.summary(); # general summayb for each sw
df # Inspect the dataframe
# Out:
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    3.3s
# 23-Nov-24 15:10:16 | WARNING | No SW were found in channel E9.
# 23-Nov-24 15:10:17 | WARNING | No SW were found in channel E45.
# 23-Nov-24 15:10:20 | WARNING | No SW were found in channel E132.
# 23-Nov-24 15:10:22 | WARNING | No SW were found in channel E186.
#            Start   NegPeak  MidCrossing   PosPeak       End  Duration  \
# 0          62.96     63.75        63.82     63.95     64.10      1.14
# 1          83.02     83.14        83.41     83.49     83.54      0.52
# 2         144.10    144.25       144.63    144.84    145.08      0.98
# 3         157.41    157.53       157.82    157.91    157.99      0.58
# 4         198.98    199.15       199.41    199.81    199.94      0.96
# ...          ...       ...          ...       ...       ...       ...
# 232395   8013.42   8013.64      8014.00   8014.12   8014.60      1.18
# 232396   8044.63   8044.79      8045.05   8045.15   8045.76      1.13
# 232397   8094.95   8095.48      8095.57   8095.66   8095.76      0.81
# 232398   8355.53   8356.12      8356.22   8356.33   8357.06      1.53
# 232399  10410.71  10410.86     10411.06  10411.16  10411.25      0.54
#
#         ValNegPeak  ValPosPeak         PTP        Slope  Frequency Channel  \
# 0       -40.843038  108.218040  149.061078  2129.443975   0.877193      E2
# 1       -66.338851   15.897654   82.236505   304.579648   1.923077      E2
# 2       -42.309507   53.274203   95.583709   251.536077   1.020408      E2
# 3       -69.818186   11.151660   80.969846   279.206367   1.724138      E2
# 4       -53.234828   29.418601   82.653429   317.897804   1.041667      E2
# ...            ...         ...         ...          ...        ...     ...
# 232395  -78.882369   29.605271  108.487640   301.354555   0.847458    E256
# 232396  -62.821096   22.815097   85.636193   329.369973   0.884956    E256
# 232397  -53.311399   54.516849  107.828248  1198.091649   1.234568    E256
# 232398  -40.587707   34.672218   75.259925   752.599254   0.653595    E256
# 232399  -73.614670   39.038434  112.653104   563.265521   1.851852    E256
#
#         IdxChannel
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 232395         197
# 232396         197
# 232397         197
# 232398         197
# 232399         197
#
# [232400 rows x 13 columns]

# %%
sw.plot_detection() # lets you scroll through the detection very conveniently

# %%
# Define the classification function
def classify_wave(start_time, pre_stim_epochs, stim_epochs, post_stim_epochs):
    """
    Classify each wave based on the start time into 'Pre-Stim', 'Stim', or 'Post-Stim' 
    and assign the protocol number.
    """
    for epochs, label in [(pre_stim_epochs, 'Pre-Stim'), 
                          (stim_epochs, 'Stim'), 
                          (post_stim_epochs, 'Post-Stim')]:
        for start, end, protocol in epochs:
            if start <= start_time <= end:
                return label, protocol
    return 'Unknown', None

# Apply classification to DataFrame 'df'
df[['Classification', 'Protocol Number']] = df['Start'].apply(
    lambda start_time: classify_wave(
        start_time,
        pre_stim_epochs, stim_epochs, post_stim_epochs
    )
).apply(pd.Series)

# Filter rows classified as 'Unknown'
df_filtered = df[df['Classification'] != 'Unknown'].reset_index(drop=True)

# %%
df
# Out:
#            Start   NegPeak  MidCrossing   PosPeak       End  Duration  \
# 0          62.96     63.75        63.82     63.95     64.10      1.14
# 1          83.02     83.14        83.41     83.49     83.54      0.52
# 2         144.10    144.25       144.63    144.84    145.08      0.98
# 3         157.41    157.53       157.82    157.91    157.99      0.58
# 4         198.98    199.15       199.41    199.81    199.94      0.96
# ...          ...       ...          ...       ...       ...       ...
# 232395   8013.42   8013.64      8014.00   8014.12   8014.60      1.18
# 232396   8044.63   8044.79      8045.05   8045.15   8045.76      1.13
# 232397   8094.95   8095.48      8095.57   8095.66   8095.76      0.81
# 232398   8355.53   8356.12      8356.22   8356.33   8357.06      1.53
# 232399  10410.71  10410.86     10411.06  10411.16  10411.25      0.54
#
#         ValNegPeak  ValPosPeak         PTP        Slope  Frequency Channel  \
# 0       -40.843038  108.218040  149.061078  2129.443975   0.877193      E2
# 1       -66.338851   15.897654   82.236505   304.579648   1.923077      E2
# 2       -42.309507   53.274203   95.583709   251.536077   1.020408      E2
# 3       -69.818186   11.151660   80.969846   279.206367   1.724138      E2
# 4       -53.234828   29.418601   82.653429   317.897804   1.041667      E2
# ...            ...         ...         ...          ...        ...     ...
# 232395  -78.882369   29.605271  108.487640   301.354555   0.847458    E256
# 232396  -62.821096   22.815097   85.636193   329.369973   0.884956    E256
# 232397  -53.311399   54.516849  107.828248  1198.091649   1.234568    E256
# 232398  -40.587707   34.672218   75.259925   752.599254   0.653595    E256
# 232399  -73.614670   39.038434  112.653104   563.265521   1.851852    E256
#
#         IdxChannel Classification  Protocol Number
# 0                0        Unknown              NaN
# 1                0        Unknown              NaN
# 2                0        Unknown              NaN
# 3                0        Unknown              NaN
# 4                0        Unknown              NaN
# ...            ...            ...              ...
# 232395         197        Unknown              NaN
# 232396         197        Unknown              NaN
# 232397         197        Unknown              NaN
# 232398         197       Pre-Stim             11.0
# 232399         197       Pre-Stim             14.0
#
# [232400 rows x 15 columns]

# %%
# Filter out rows where 'Protocol Number' is NaN
df_filtered = df.dropna(subset=['Protocol Number'])

# Generate the slow wave names
df_filtered['Slow_Wave_Name' ] = (
    'proto' + df_filtered['Protocol Number'].astype(int).astype(str) + '_' +
    df_filtered['Classification'].str.lower().str.replace(' ', '-') + '_sw' +
    (df_filtered.groupby(['Protocol Number', 'Classification']).cumcount() + 1).astype(str)
)

# Define the order for the 'Classification'
classification_order = ['pre-stim', 'stim', 'post-stim']

# Create a categorical type for sorting Classification
df_filtered['Classification'] = df_filtered['Classification'].str.lower().str.replace(' ', '-')
df_filtered['Classification'] = pd.Categorical(df_filtered['Classification'], categories=classification_order, ordered=True)

# Sort the DataFrame based on Protocol Number, Classification order, and Slow Wave Name
df_sorted = df_filtered.sort_values(by=['Protocol Number', 'Classification', 'Slow_Wave_Name'])

# Keep only the relevant columns
df_epochs = df_sorted[['Slow_Wave_Name', 'Start', 'End', 'Duration', 
                       'NegPeak', 'PosPeak', 'ValNegPeak', 'ValPosPeak', 
                       'Protocol Number', 'Classification', 'Channel']]

# Display the DataFrame with the new columns
print(df_epochs.head())

# Save the resulting DataFrame to a CSV file
df_epochs.to_csv('sorted_slow_waves.csv', index=False)
# Out:
# /var/folders/0y/xvbtt0c135x04tpfn8c89v300000gn/T/ipykernel_6411/2783400664.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Slow_Wave_Name' ] = (
# /var/folders/0y/xvbtt0c135x04tpfn8c89v300000gn/T/ipykernel_6411/2783400664.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Classification'] = df_filtered['Classification'].str.lower().str.replace(' ', '-')
# /var/folders/0y/xvbtt0c135x04tpfn8c89v300000gn/T/ipykernel_6411/2783400664.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Classification'] = pd.Categorical(df_filtered['Classification'], categories=classification_order, ordered=True)
#                Slow_Wave_Name   Start     End  Duration  NegPeak  PosPeak  \
# 6         proto1_pre-stim_sw1  389.76  390.50      0.74   389.86   390.24
# 15       proto1_pre-stim_sw10  454.82  455.51      0.69   455.02   455.42
# 9359    proto1_pre-stim_sw100  455.49  456.34      0.85   455.62   456.01
# 84775  proto1_pre-stim_sw1000  356.65  357.44      0.79   356.86   357.13
# 84776  proto1_pre-stim_sw1001  380.86  381.74      0.88   381.02   381.41
#
#        ValNegPeak  ValPosPeak  Protocol Number Classification Channel
# 6      -45.324543   40.681746              1.0       pre-stim      E2
# 15     -99.037309   60.448043              1.0       pre-stim      E2
# 9359   -51.307500   76.539914              1.0       pre-stim     E14
# 84775  -61.445404   57.653407              1.0       pre-stim    E123
# 84776  -60.053981   23.689135              1.0       pre-stim    E123

# %%
# Function to filter epochs based on window size and picking criteria
def filter_epochs(df, window_size, pick_most_negative=False):
    """
    Filters epochs based on a specified window size. Optionally picks the wave 
    with the most negative ValNegPeak within the window.

    Parameters:
        df (pd.DataFrame): Input DataFrame with epoch information.
        window_size (float): Minimum time gap (in seconds) between waves.
        pick_most_negative (bool): Whether to pick the wave with the most negative ValNegPeak.

    Returns:
        pd.DataFrame: Filtered DataFrame.
    """
    filtered_epochs_list = []
    last_end_time = -float('inf')
    current_window = []

    for _, row in df_sorted.iterrows():
        if row['Start'] > last_end_time + window_size:
            if current_window:
                selected_wave = (
                    min(current_window, key=lambda x: x['ValNegPeak']) 
                    if pick_most_negative else current_window[0]
                )
                filtered_epochs_list.append(selected_wave)
            current_window = [row]
            last_end_time = row['End']
        else:
            current_window.append(row)

    # Process the last window
    if current_window:
        selected_wave = (
            min(current_window, key=lambda x: x['ValNegPeak']) 
            if pick_most_negative else current_window[0]
        )
        filtered_epochs_list.append(selected_wave)

    # Convert list of dictionaries to DataFrame to retain all original columns
    return pd.DataFrame(filtered_epochs_list)

# Apply the filtering and save to CSV files, ensuring all relevant columns are included
windows = [0.5, 1.0]  # Window sizes in seconds
for window in windows:
    for pick_negative in [False, True]:
        suffix = "most_negative" if pick_negative else "first"
        filename = f'filtered_epochs_{int(window*1000)}ms_{suffix}.csv'
        filtered_epochs = filter_epochs(df, window_size=window, pick_most_negative=pick_negative)
        filtered_epochs.to_csv(filename, index=False)
        print(f"Filtered epochs saved to {filename}")
# Out:
# Filtered epochs saved to filtered_epochs_500ms_first.csv
# Filtered epochs saved to filtered_epochs_500ms_most_negative.csv
# Filtered epochs saved to filtered_epochs_1000ms_first.csv
# Filtered epochs saved to filtered_epochs_1000ms_most_negative.csv

# %%
# Load the filtered epochs data
df_actual = pd.read_csv('filtered_epochs_500ms_most_negative.csv')

# Define the specific columns to analyze
columns_to_plot = ['Duration', 'ValNegPeak', 'ValPosPeak', 'PTP', 'Frequency']

# Define all possible classifications
all_classifications = ['pre-stim', 'stim', 'post-stim']

# Filter and group by Classification for overall analysis
comparison_means = df_actual.groupby('Classification')[columns_to_plot].mean().reindex(all_classifications, fill_value=0)
comparison_counts = df_actual['Classification'].value_counts().reindex(all_classifications, fill_value=0)

# Function to add value labels on bars
def add_value_labels(ax, spacing=5):
    """Add labels to the end of each bar in a bar chart."""
    for rect in ax.patches:
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2
        label = f"{y_value:.2f}" if y_value != 0 else "0"  # Use a single zero for labels with no decimal part
        ax.annotate(
            label, 
            (x_value, y_value), 
            xytext=(0, spacing), 
            textcoords="offset points", 
            ha='center', 
            va='bottom'
        )

# Figure 1: Overall comparison for all classifications combined, disregarding protocol number
plt.figure(figsize=(15, 6))

# Overall Mean Values Plot
plt.subplot(1, 2, 1)
ax = comparison_means.plot(kind='bar', ax=plt.gca(), color=['#6baed6', '#bdd7e7', '#eff3ff', '#fdbe85', '#fd8d3c'])
plt.title('Overall Mean Values of Wave Properties (All Protocols Combined)')
plt.ylabel('Mean Values')
plt.xlabel('Classification', labelpad=10)
plt.xticks(rotation=0)
plt.legend(title='Properties', loc='upper left', bbox_to_anchor=(1, 1))  # Moving the legend outside
add_value_labels(ax)  # Add value labels

# Overall Count Plot
plt.subplot(1, 2, 2)
ax2 = comparison_counts.plot(kind='bar', color='#6baed6', ax=plt.gca())
plt.title('Overall Count of Instances by Classification (All Protocols Combined)')
plt.ylabel('Count')
plt.xlabel('Classification', labelpad=10)
plt.xticks(rotation=0)
add_value_labels(ax2)  # Add value labels

# Show the overall plot
plt.tight_layout()  # Adjusts subplots to give some padding and prevent overlap
plt.show()

# Now, let's create separate plots for each protocol
protocol_numbers = df_actual['Protocol Number'].dropna().unique()  # Get unique protocol numbers

for protocol in protocol_numbers:
    protocol_data = df_actual[df_actual['Protocol Number'] == protocol]
    protocol_means = protocol_data.groupby('Classification')[columns_to_plot].mean().reindex(all_classifications, fill_value=0)
    protocol_counts = protocol_data['Classification'].value_counts().reindex(all_classifications, fill_value=0)

    plt.figure(figsize=(15, 6))

    # Mean values for each protocol
    plt.subplot(1, 2, 1)
    ax = protocol_means.plot(kind='bar', ax=plt.gca(), color=['#6baed6', '#bdd7e7', '#eff3ff', '#fdbe85', '#fd8d3c'])
    plt.title(f'Mean Values of Wave Properties (Protocol {int(protocol)})')
    plt.ylabel('Mean Values')
    plt.xlabel('Classification', labelpad=10)
    plt.xticks(rotation=0)
    plt.legend(title='Properties', loc='upper left', bbox_to_anchor=(1, 1))  # Moving the legend outside
    add_value_labels(ax)  # Add value labels

    # Counts for each protocol
    plt.subplot(1, 2, 2)
    ax2 = protocol_counts.plot(kind='bar', color='#6baed6', ax=plt.gca())
    plt.title(f'Count of Instances by Classification (Protocol {int(protocol)})')
    plt.ylabel('Count')
    plt.xlabel('Classification', labelpad=10)
    plt.xticks(rotation=0)
    add_value_labels(ax2)  # Add value labels

    # Show the plots for this protocol
    plt.tight_layout()
    plt.show()

# %%
# Load the CSV file into a DataFrame
events_df = pd.read_csv('filtered_epochs_500ms_most_negative.csv')

# Initialize lists to hold annotation data
onsets, durations, descriptions = [], [], []

# Populate the annotation lists for the main events
for _, row in events_df.iterrows():
    # Add the "Start" event
    onsets.append(row['Start'])  # Start time in seconds
    durations.append(0)  # Instantaneous event
    descriptions.append("Start")
    
    # Add the "NegPeak" event
    onsets.append(row['NegPeak'])  # Time of negative peak
    durations.append(0)  # Instantaneous event
    descriptions.append("NegPeak")
    
    # Add the "PosPeak" event
    onsets.append(row['PosPeak'])  # Time of positive peak
    durations.append(0)  # Instantaneous event
    descriptions.append("PosPeak")
    
    # Add the "End" event
    onsets.append(row['End'])  # End time in seconds
    durations.append(0)  # Instantaneous event
    descriptions.append("End")

# Create an MNE Annotations object
annotations = mne.Annotations(onset=onsets, duration=durations, description=descriptions)

# Add the annotations to the raw data
raw.set_annotations(annotations)

# Export the annotated raw data to an EEGLAB .set file
output_fname = 'annotated_raw.set'
mne.export.export_raw(output_fname, raw, fmt='eeglab')

# Verify the annotations
print("Available annotation descriptions:")
print(set(annotations.description))
# Out:
# Available annotation descriptions:
# {'Start', 'PosPeak', 'End', 'NegPeak'}

# %%
fname = 'annotated_raw.set'
annotated= mne.io.read_raw_eeglab(fname, preload=True)
annotated
annotated.plot(clipping=None, duration=5)
annotated.info['sfreq']
# Out:
# Using matplotlib as 2D backend.
# 100.0
# Channels marked as bad:
# none

# %%
# Define input CSV and output directory
extraction_file = 'filtered_epochs_500ms_first.csv'
output_dir = 'epoch-imgs'
os.makedirs(output_dir, exist_ok=True)

# Load the extraction data into a DataFrame
extraction_df = pd.read_csv(extraction_file)

# Loop through each row in the DataFrame
for i, row in extraction_df.iterrows():
    # Convert 'Start', 'NegPeak', 'PosPeak', and 'End' times to sample indices
    start_sample = int(row['Start'] * sf)
    neg_peak_sample = int(row['NegPeak'] * sf)
    pos_peak_sample = int(row['PosPeak'] * sf)
    end_sample = int(row['End'] * sf)

    # Calculate tmin and tmax based on the 'Start' and 'End' times
    tmin = 0  # Start aligned at 0
    tmax = (end_sample - start_sample) / sf  # Duration from Start to End

    # Create an event array for the 'Start' event only
    events = np.array([[start_sample, 0, 1]])  # Event code 1 for 'Start'

    # Create the epoch using the 'Start' event
    try:
        epoch = mne.Epochs(
            raw, events, event_id={'Start': 1},
            tmin=tmin, tmax=tmax, baseline=None, preload=True
        )
    except ValueError as e:
        print(f"Error creating epoch for row {i}: {e}")
        continue

    # Convert NegPeak, PosPeak, and End times to seconds relative to the epoch start
    neg_peak_time = (neg_peak_sample - start_sample) / sf
    pos_peak_time = (pos_peak_sample - start_sample) / sf
    end_time = (end_sample - start_sample) / sf

    # Retrieve the selected channel and slow wave name
    selected_channel = row['Channel']
    slow_wave_name = row['Slow_Wave_Name']

    # Validate the selected channel
    if selected_channel not in raw.ch_names:
        print(f"Channel {selected_channel} not found in raw data for row {i}. Skipping.")
        continue

    # Get the index of the selected channel
    channel_idx = raw.ch_names.index(selected_channel)

    # Create a plot for the epoch without opening the image
    fig, ax = plt.subplots(figsize=(10, 4))

    # Plot the data for the selected channel
    epoch_data = epoch.get_data(picks=[channel_idx])[0, 0, :]  # Get data for the selected channel
    times = epoch.times  # Times corresponding to the epoch

    ax.plot(times, epoch_data, color='black', label='EEG Signal')

    # Add vertical dashed lines for Start, NegPeak, PosPeak, and End
    ax.axvline(0, color='black', linestyle='--', label='Start')  # Start event
    ax.axvline(neg_peak_time, color='red', linestyle='--', label='NegPeak')
    ax.axvline(pos_peak_time, color='green', linestyle='--', label='PosPeak')
    ax.axvline(end_time, color='blue', linestyle='--', label='End')

    # Set labels and title
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Amplitude (V)')
    ax.set_title(f"{slow_wave_name} // {selected_channel}")
    ax.legend(loc='upper right')

    # Save the figure to the output directory without opening it
    output_path = os.path.join(output_dir, f'{slow_wave_name}_{selected_channel}.png')
    fig.savefig(output_path)
    plt.close(fig)  # Close the figure to save memory

print("Processing complete. All epoch images were saved in the 'epoch-imgs' directory.")
# Out:
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 75 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 70 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 129 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 68 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 76 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 100 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 76 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 66 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 82 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 109 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 126 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 64 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 114 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 127 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 62 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 103 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 87 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 104 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 83 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 50 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 68 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 136 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 121 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 106 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 99 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 102 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 104 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 133 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 93 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 75 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 86 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 69 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 60 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 106 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 115 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 83 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 85 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 73 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 54 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 55 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 85 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 81 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 77 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 122 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 79 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 138 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 70 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 113 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 93 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 75 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 114 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 79 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 59 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 84 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 107 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 94 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 137 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 111 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 91 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 84 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 170 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 144 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 80 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 67 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 99 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 79 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 83 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 92 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 67 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 94 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 84 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 77 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 66 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 56 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 92 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 114 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 87 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 67 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 78 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 69 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 69 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 83 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 81 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 49 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 68 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 80 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 71 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 87 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 64 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 67 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 99 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 71 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 71 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 87 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 95 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 81 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 56 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 76 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 80 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 81 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 110 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 90 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 103 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 106 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 51 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 53 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 60 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 161 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 133 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 98 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 119 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 55 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 126 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 118 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 85 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 105 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 65 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 128 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 103 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 78 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 60 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 70 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 122 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 84 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 117 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 127 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 86 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 61 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 60 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 78 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 50 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 84 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 92 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 111 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 63 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 81 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 89 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 84 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 59 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 120 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 103 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 123 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 110 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 122 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 58 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 91 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 83 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 92 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 128 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 133 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 162 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 77 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 126 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 95 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 78 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 140 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 92 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 119 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 139 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 61 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 76 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 69 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 87 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 116 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 95 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 60 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 110 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 54 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 66 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 82 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 148 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 51 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 57 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 65 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 115 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 58 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 108 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 69 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 71 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 93 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 105 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 69 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 118 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 55 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 98 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 77 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 120 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 91 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 95 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 97 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 120 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 118 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 89 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 69 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 83 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 114 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 102 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 121 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 87 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 100 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 78 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 109 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 95 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 93 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 125 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 58 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 104 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# ...
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 61 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 131 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 65 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 82 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 112 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 158 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 72 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 92 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 68 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 117 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 103 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 107 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 88 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 65 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 65 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 102 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 140 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 57 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 138 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 117 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 122 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 126 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 119 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 81 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 150 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 106 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 154 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 103 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 105 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 65 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 54 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 145 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 80 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 94 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 106 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 90 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 85 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 74 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 102 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 154 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 123 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 111 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 95 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 131 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 125 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 91 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 138 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 70 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 126 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 68 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 89 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 61 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 128 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 82 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 89 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 117 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 106 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 90 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 84 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 121 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 73 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 67 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 140 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 97 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 105 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 151 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 164 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 149 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 85 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 155 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 57 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 61 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 136 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 162 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 147 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 140 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 136 original time points ...
# 0 bad epochs dropped
# Processing complete. All epoch images were saved in the 'epoch-imgs' directory.

# %%
# Directory where you want to save the files
output_dir = "epoch-data"
os.makedirs(output_dir, exist_ok=True)

# Sampling frequency from the MNE raw object
sfreq = raw.info['sfreq']

# Define the baseline duration in seconds
baseline_duration = 0.2  # 0.2 seconds
baseline_samples = int(baseline_duration * sfreq)

# Loop through each row in the filtered CSV DataFrame
for i in range(len(extraction_df)):
    # Extract data and info for the ith epoch
    row = extraction_df.iloc[i]
    
    start_time = row['Start']
    neg_peak_time = row['NegPeak']
    pos_peak_time = row['PosPeak']
    end_time = row['End']

    # Calculate the new start time with baseline
    new_start_time = start_time - baseline_duration
    
    # Ensure that the new start time is not negative
    if new_start_time < 0:
        new_start_time = 0

    # Convert times to samples
    new_start_sample = int(new_start_time * sfreq)
    start_sample = int(start_time * sfreq)
    end_sample = int(end_time * sfreq)
    
    # Extract the epoch data with the baseline
    epoch_data = raw.get_data(start=new_start_sample, stop=end_sample + 1)
    info = raw.info

    # Create RawArray from epoch data
    raw_epoch = mne.io.RawArray(epoch_data, info)
    
    # Calculate the event sample points relative to the new start time
    neg_peak_sample = int((neg_peak_time - new_start_time) * sfreq)
    pos_peak_sample = int((pos_peak_time - new_start_time) * sfreq)
    start_event_sample = baseline_samples  # Start event is at baseline

    # Create events array
    events = np.array([
        [start_event_sample, 0, 1],  # Start event after the baseline
        [neg_peak_sample, 0, 2],     # NegPeak event
        [pos_peak_sample, 0, 3],     # PosPeak event
    ])
    
    # Add events to annotations
    annotations = mne.Annotations(onset=events[:, 0] / sfreq,
                                  duration=[0, 0, 0],
                                  description=['Start', 'NegPeak', 'PosPeak'])
    raw_epoch.set_annotations(annotations)
    
    # Get the epoch name and channel from the CSV file
    epoch_name = row['Slow_Wave_Name']
    channel_name = row['Channel']
    
    # Naming scheme for the file: "Slow_Wave_Name_Channel"
    file_name = f"{epoch_name}_{channel_name}.set"
    
    # Save as .set file directly in the output directory
    epoch_file = os.path.join(output_dir, file_name)
    mne.export.export_raw(epoch_file, raw_epoch, fmt='eeglab')
    print(f"Saved epoch '{file_name}' to {epoch_file}")

print("All epochs have been successfully saved as .set files in the 'epoch-data' directory.")
# Out:
# Creating RawArray with float64 data, n_channels=198, n_times=95
#     Range : 0 ... 94 =      0.000 ...     0.940 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1_E2.set' to epoch-data/proto1_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=90
#     Range : 0 ... 89 =      0.000 ...     0.890 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw10_E2.set' to epoch-data/proto1_pre-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=149
#     Range : 0 ... 148 =      0.000 ...     1.480 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw101_E14.set' to epoch-data/proto1_pre-stim_sw101_E14.set
# Creating RawArray with float64 data, n_channels=198, n_times=88
#     Range : 0 ... 87 =      0.000 ...     0.870 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1013_E123.set' to epoch-data/proto1_pre-stim_sw1013_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1014_E123.set' to epoch-data/proto1_pre-stim_sw1014_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=96
#     Range : 0 ... 95 =      0.000 ...     0.950 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1015_E123.set' to epoch-data/proto1_pre-stim_sw1015_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=120
#     Range : 0 ... 119 =      0.000 ...     1.190 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1017_E123.set' to epoch-data/proto1_pre-stim_sw1017_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=97
#     Range : 0 ... 96 =      0.000 ...     0.960 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1018_E123.set' to epoch-data/proto1_pre-stim_sw1018_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=133
#     Range : 0 ... 132 =      0.000 ...     1.320 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1019_E123.set' to epoch-data/proto1_pre-stim_sw1019_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=134
#     Range : 0 ... 133 =      0.000 ...     1.330 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1020_E123.set' to epoch-data/proto1_pre-stim_sw1020_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=86
#     Range : 0 ... 85 =      0.000 ...     0.850 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1021_E123.set' to epoch-data/proto1_pre-stim_sw1021_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=103
#     Range : 0 ... 102 =      0.000 ...     1.020 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1022_E123.set' to epoch-data/proto1_pre-stim_sw1022_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=130
#     Range : 0 ... 129 =      0.000 ...     1.290 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1023_E123.set' to epoch-data/proto1_pre-stim_sw1023_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=109
#     Range : 0 ... 108 =      0.000 ...     1.080 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw1024_E123.set' to epoch-data/proto1_pre-stim_sw1024_E123.set
# Creating RawArray with float64 data, n_channels=198, n_times=83
#     Range : 0 ... 82 =      0.000 ...     0.820 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw2167_E211.set' to epoch-data/proto1_pre-stim_sw2167_E211.set
# Creating RawArray with float64 data, n_channels=198, n_times=84
#     Range : 0 ... 83 =      0.000 ...     0.830 secs
# Ready.
# Saved epoch 'proto1_pre-stim_sw325_E46.set' to epoch-data/proto1_pre-stim_sw325_E46.set
# Creating RawArray with float64 data, n_channels=198, n_times=146
#     Range : 0 ... 145 =      0.000 ...     1.450 secs
# Ready.
# Saved epoch 'proto1_stim_sw1_E2.set' to epoch-data/proto1_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=85
#     Range : 0 ... 84 =      0.000 ...     0.840 secs
# Ready.
# Saved epoch 'proto1_stim_sw10_E2.set' to epoch-data/proto1_stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=134
#     Range : 0 ... 133 =      0.000 ...     1.330 secs
# Ready.
# Saved epoch 'proto1_stim_sw100_E16.set' to epoch-data/proto1_stim_sw100_E16.set
# Creating RawArray with float64 data, n_channels=198, n_times=147
#     Range : 0 ... 146 =      0.000 ...     1.460 secs
# Ready.
# Saved epoch 'proto1_stim_sw1000_E135.set' to epoch-data/proto1_stim_sw1000_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=82
#     Range : 0 ... 81 =      0.000 ...     0.810 secs
# Ready.
# Saved epoch 'proto1_stim_sw1001_E135.set' to epoch-data/proto1_stim_sw1001_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=123
#     Range : 0 ... 122 =      0.000 ...     1.220 secs
# Ready.
# Saved epoch 'proto1_stim_sw1002_E135.set' to epoch-data/proto1_stim_sw1002_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=107
#     Range : 0 ... 106 =      0.000 ...     1.060 secs
# Ready.
# Saved epoch 'proto1_stim_sw1003_E135.set' to epoch-data/proto1_stim_sw1003_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=124
#     Range : 0 ... 123 =      0.000 ...     1.230 secs
# Ready.
# Saved epoch 'proto1_stim_sw1004_E135.set' to epoch-data/proto1_stim_sw1004_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto1_stim_sw1005_E135.set' to epoch-data/proto1_stim_sw1005_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=70
#     Range : 0 ... 69 =      0.000 ...     0.690 secs
# Ready.
# Saved epoch 'proto1_stim_sw1006_E135.set' to epoch-data/proto1_stim_sw1006_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto1_stim_sw1007_E135.set' to epoch-data/proto1_stim_sw1007_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=157
#     Range : 0 ... 156 =      0.000 ...     1.560 secs
# Ready.
# Saved epoch 'proto1_stim_sw1008_E135.set' to epoch-data/proto1_stim_sw1008_E135.set
# Creating RawArray with float64 data, n_channels=198, n_times=142
#     Range : 0 ... 141 =      0.000 ...     1.410 secs
# Ready.
# Saved epoch 'proto1_stim_sw120_E18.set' to epoch-data/proto1_stim_sw120_E18.set
# Creating RawArray with float64 data, n_channels=198, n_times=126
#     Range : 0 ... 125 =      0.000 ...     1.250 secs
# Ready.
# Saved epoch 'proto1_post-stim_sw1_E2.set' to epoch-data/proto1_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=119
#     Range : 0 ... 118 =      0.000 ...     1.180 secs
# Ready.
# Saved epoch 'proto1_post-stim_sw10_E2.set' to epoch-data/proto1_post-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=123
#     Range : 0 ... 122 =      0.000 ...     1.220 secs
# Ready.
# Saved epoch 'proto1_post-stim_sw100_E5.set' to epoch-data/proto1_post-stim_sw100_E5.set
# Creating RawArray with float64 data, n_channels=198, n_times=124
#     Range : 0 ... 123 =      0.000 ...     1.230 secs
# Ready.
# Saved epoch 'proto1_post-stim_sw101_E5.set' to epoch-data/proto1_post-stim_sw101_E5.set
# Creating RawArray with float64 data, n_channels=198, n_times=153
#     Range : 0 ... 152 =      0.000 ...     1.520 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw1_E2.set' to epoch-data/proto2_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=113
#     Range : 0 ... 112 =      0.000 ...     1.120 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw10_E2.set' to epoch-data/proto2_pre-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=96
#     Range : 0 ... 95 =      0.000 ...     0.950 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw100_E4.set' to epoch-data/proto2_pre-stim_sw100_E4.set
# Creating RawArray with float64 data, n_channels=198, n_times=106
#     Range : 0 ... 105 =      0.000 ...     1.050 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw1000_E85.set' to epoch-data/proto2_pre-stim_sw1000_E85.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw1027_E87.set' to epoch-data/proto2_pre-stim_sw1027_E87.set
# Creating RawArray with float64 data, n_channels=198, n_times=80
#     Range : 0 ... 79 =      0.000 ...     0.790 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw1069_E91.set' to epoch-data/proto2_pre-stim_sw1069_E91.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw1070_E91.set' to epoch-data/proto2_pre-stim_sw1070_E91.set
# Creating RawArray with float64 data, n_channels=198, n_times=126
#     Range : 0 ... 125 =      0.000 ...     1.250 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw111_E4.set' to epoch-data/proto2_pre-stim_sw111_E4.set
# Creating RawArray with float64 data, n_channels=198, n_times=135
#     Range : 0 ... 134 =      0.000 ...     1.340 secs
# Ready.
# Saved epoch 'proto2_pre-stim_sw112_E4.set' to epoch-data/proto2_pre-stim_sw112_E4.set
# Creating RawArray with float64 data, n_channels=198, n_times=84
#     Range : 0 ... 83 =      0.000 ...     0.830 secs
# Ready.
# Saved epoch 'proto2_stim_sw1_E2.set' to epoch-data/proto2_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=94
#     Range : 0 ... 93 =      0.000 ...     0.930 secs
# Ready.
# Saved epoch 'proto2_stim_sw10_E2.set' to epoch-data/proto2_stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=103
#     Range : 0 ... 102 =      0.000 ...     1.020 secs
# Ready.
# Saved epoch 'proto2_stim_sw1000_E73.set' to epoch-data/proto2_stim_sw1000_E73.set
# Creating RawArray with float64 data, n_channels=198, n_times=105
#     Range : 0 ... 104 =      0.000 ...     1.040 secs
# Ready.
# Saved epoch 'proto2_stim_sw1001_E73.set' to epoch-data/proto2_stim_sw1001_E73.set
# Creating RawArray with float64 data, n_channels=198, n_times=93
#     Range : 0 ... 92 =      0.000 ...     0.920 secs
# Ready.
# Saved epoch 'proto2_stim_sw1002_E73.set' to epoch-data/proto2_stim_sw1002_E73.set
# Creating RawArray with float64 data, n_channels=198, n_times=74
#     Range : 0 ... 73 =      0.000 ...     0.730 secs
# Ready.
# Saved epoch 'proto2_stim_sw1004_E73.set' to epoch-data/proto2_stim_sw1004_E73.set
# Creating RawArray with float64 data, n_channels=198, n_times=75
#     Range : 0 ... 74 =      0.000 ...     0.740 secs
# Ready.
# Saved epoch 'proto2_stim_sw1005_E73.set' to epoch-data/proto2_stim_sw1005_E73.set
# Creating RawArray with float64 data, n_channels=198, n_times=105
#     Range : 0 ... 104 =      0.000 ...     1.040 secs
# Ready.
# Saved epoch 'proto2_stim_sw1006_E73.set' to epoch-data/proto2_stim_sw1006_E73.set
# Creating RawArray with float64 data, n_channels=198, n_times=101
#     Range : 0 ... 100 =      0.000 ...     1.000 secs
# Ready.
# Saved epoch 'proto2_stim_sw1113_E85.set' to epoch-data/proto2_stim_sw1113_E85.set
# Creating RawArray with float64 data, n_channels=198, n_times=97
#     Range : 0 ... 96 =      0.000 ...     0.960 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw1_E2.set' to epoch-data/proto2_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=142
#     Range : 0 ... 141 =      0.000 ...     1.410 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw10_E2.set' to epoch-data/proto2_post-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=99
#     Range : 0 ... 98 =      0.000 ...     0.980 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw100_E3.set' to epoch-data/proto2_post-stim_sw100_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=158
#     Range : 0 ... 157 =      0.000 ...     1.570 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw101_E3.set' to epoch-data/proto2_post-stim_sw101_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=90
#     Range : 0 ... 89 =      0.000 ...     0.890 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw102_E3.set' to epoch-data/proto2_post-stim_sw102_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=133
#     Range : 0 ... 132 =      0.000 ...     1.320 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw103_E3.set' to epoch-data/proto2_post-stim_sw103_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=114
#     Range : 0 ... 113 =      0.000 ...     1.130 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw1049_E37.set' to epoch-data/proto2_post-stim_sw1049_E37.set
# Creating RawArray with float64 data, n_channels=198, n_times=95
#     Range : 0 ... 94 =      0.000 ...     0.940 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw105_E3.set' to epoch-data/proto2_post-stim_sw105_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=134
#     Range : 0 ... 133 =      0.000 ...     1.330 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw1051_E37.set' to epoch-data/proto2_post-stim_sw1051_E37.set
# Creating RawArray with float64 data, n_channels=198, n_times=99
#     Range : 0 ... 98 =      0.000 ...     0.980 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw1053_E37.set' to epoch-data/proto2_post-stim_sw1053_E37.set
# Creating RawArray with float64 data, n_channels=198, n_times=79
#     Range : 0 ... 78 =      0.000 ...     0.780 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw1055_E37.set' to epoch-data/proto2_post-stim_sw1055_E37.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw1056_E37.set' to epoch-data/proto2_post-stim_sw1056_E37.set
# Creating RawArray with float64 data, n_channels=198, n_times=127
#     Range : 0 ... 126 =      0.000 ...     1.260 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw1058_E37.set' to epoch-data/proto2_post-stim_sw1058_E37.set
# Creating RawArray with float64 data, n_channels=198, n_times=114
#     Range : 0 ... 113 =      0.000 ...     1.130 secs
# Ready.
# Saved epoch 'proto2_post-stim_sw118_E3.set' to epoch-data/proto2_post-stim_sw118_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=157
#     Range : 0 ... 156 =      0.000 ...     1.560 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw1_E2.set' to epoch-data/proto3_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=131
#     Range : 0 ... 130 =      0.000 ...     1.300 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10_E2.set' to epoch-data/proto3_pre-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=111
#     Range : 0 ... 110 =      0.000 ...     1.100 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw100_E3.set' to epoch-data/proto3_pre-stim_sw100_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw1000_E27.set' to epoch-data/proto3_pre-stim_sw1000_E27.set
# Creating RawArray with float64 data, n_channels=198, n_times=190
#     Range : 0 ... 189 =      0.000 ...     1.890 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10000_E230.set' to epoch-data/proto3_pre-stim_sw10000_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=164
#     Range : 0 ... 163 =      0.000 ...     1.630 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10002_E230.set' to epoch-data/proto3_pre-stim_sw10002_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=100
#     Range : 0 ... 99 =      0.000 ...     0.990 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10004_E230.set' to epoch-data/proto3_pre-stim_sw10004_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=87
#     Range : 0 ... 86 =      0.000 ...     0.860 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10005_E230.set' to epoch-data/proto3_pre-stim_sw10005_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=119
#     Range : 0 ... 118 =      0.000 ...     1.180 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10007_E230.set' to epoch-data/proto3_pre-stim_sw10007_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=99
#     Range : 0 ... 98 =      0.000 ...     0.980 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10008_E230.set' to epoch-data/proto3_pre-stim_sw10008_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10009_E230.set' to epoch-data/proto3_pre-stim_sw10009_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=103
#     Range : 0 ... 102 =      0.000 ...     1.020 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10010_E230.set' to epoch-data/proto3_pre-stim_sw10010_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=112
#     Range : 0 ... 111 =      0.000 ...     1.110 secs
# Ready.
# Saved epoch 'proto3_pre-stim_sw10011_E230.set' to epoch-data/proto3_pre-stim_sw10011_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=87
#     Range : 0 ... 86 =      0.000 ...     0.860 secs
# Ready.
# Saved epoch 'proto3_stim_sw10_E2.set' to epoch-data/proto3_stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=114
#     Range : 0 ... 113 =      0.000 ...     1.130 secs
# Ready.
# Saved epoch 'proto3_stim_sw1000_E22.set' to epoch-data/proto3_stim_sw1000_E22.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto3_stim_sw10000_E188.set' to epoch-data/proto3_stim_sw10000_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=97
#     Range : 0 ... 96 =      0.000 ...     0.960 secs
# Ready.
# Saved epoch 'proto3_stim_sw10001_E188.set' to epoch-data/proto3_stim_sw10001_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=86
#     Range : 0 ... 85 =      0.000 ...     0.850 secs
# Ready.
# Saved epoch 'proto3_stim_sw10002_E188.set' to epoch-data/proto3_stim_sw10002_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=76
#     Range : 0 ... 75 =      0.000 ...     0.750 secs
# Ready.
# Saved epoch 'proto3_stim_sw10003_E188.set' to epoch-data/proto3_stim_sw10003_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=112
#     Range : 0 ... 111 =      0.000 ...     1.110 secs
# Ready.
# Saved epoch 'proto3_stim_sw10004_E188.set' to epoch-data/proto3_stim_sw10004_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=134
#     Range : 0 ... 133 =      0.000 ...     1.330 secs
# Ready.
# Saved epoch 'proto3_stim_sw10006_E188.set' to epoch-data/proto3_stim_sw10006_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=106
#     Range : 0 ... 105 =      0.000 ...     1.050 secs
# Ready.
# Saved epoch 'proto3_stim_sw10008_E188.set' to epoch-data/proto3_stim_sw10008_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto3_stim_sw10009_E188.set' to epoch-data/proto3_stim_sw10009_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=87
#     Range : 0 ... 86 =      0.000 ...     0.860 secs
# Ready.
# Saved epoch 'proto3_stim_sw10010_E188.set' to epoch-data/proto3_stim_sw10010_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=98
#     Range : 0 ... 97 =      0.000 ...     0.970 secs
# Ready.
# Saved epoch 'proto3_stim_sw10011_E188.set' to epoch-data/proto3_stim_sw10011_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto3_stim_sw10013_E188.set' to epoch-data/proto3_stim_sw10013_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto3_stim_sw10015_E188.set' to epoch-data/proto3_stim_sw10015_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=103
#     Range : 0 ... 102 =      0.000 ...     1.020 secs
# Ready.
# Saved epoch 'proto3_stim_sw10016_E188.set' to epoch-data/proto3_stim_sw10016_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=101
#     Range : 0 ... 100 =      0.000 ...     1.000 secs
# Ready.
# Saved epoch 'proto3_stim_sw10017_E188.set' to epoch-data/proto3_stim_sw10017_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=69
#     Range : 0 ... 68 =      0.000 ...     0.680 secs
# Ready.
# Saved epoch 'proto3_stim_sw10019_E188.set' to epoch-data/proto3_stim_sw10019_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=88
#     Range : 0 ... 87 =      0.000 ...     0.870 secs
# Ready.
# Saved epoch 'proto3_stim_sw10020_E188.set' to epoch-data/proto3_stim_sw10020_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=100
#     Range : 0 ... 99 =      0.000 ...     0.990 secs
# Ready.
# Saved epoch 'proto3_stim_sw10022_E188.set' to epoch-data/proto3_stim_sw10022_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=82
#     Range : 0 ... 81 =      0.000 ...     0.810 secs
# Ready.
# Saved epoch 'proto3_stim_sw10024_E188.set' to epoch-data/proto3_stim_sw10024_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=90
#     Range : 0 ... 89 =      0.000 ...     0.890 secs
# Ready.
# Saved epoch 'proto3_stim_sw10025_E188.set' to epoch-data/proto3_stim_sw10025_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=107
#     Range : 0 ... 106 =      0.000 ...     1.060 secs
# Ready.
# Saved epoch 'proto3_stim_sw10026_E188.set' to epoch-data/proto3_stim_sw10026_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=83
#     Range : 0 ... 82 =      0.000 ...     0.820 secs
# Ready.
# Saved epoch 'proto3_stim_sw10028_E188.set' to epoch-data/proto3_stim_sw10028_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=84
#     Range : 0 ... 83 =      0.000 ...     0.830 secs
# Ready.
# Saved epoch 'proto3_stim_sw10030_E188.set' to epoch-data/proto3_stim_sw10030_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=86
#     Range : 0 ... 85 =      0.000 ...     0.850 secs
# Ready.
# Saved epoch 'proto3_stim_sw10031_E188.set' to epoch-data/proto3_stim_sw10031_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=83
#     Range : 0 ... 82 =      0.000 ...     0.820 secs
# Ready.
# Saved epoch 'proto3_stim_sw10032_E188.set' to epoch-data/proto3_stim_sw10032_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=118
#     Range : 0 ... 117 =      0.000 ...     1.170 secs
# Ready.
# Saved epoch 'proto3_stim_sw10033_E188.set' to epoch-data/proto3_stim_sw10033_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=90
#     Range : 0 ... 89 =      0.000 ...     0.890 secs
# Ready.
# Saved epoch 'proto3_stim_sw10034_E188.set' to epoch-data/proto3_stim_sw10034_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=91
#     Range : 0 ... 90 =      0.000 ...     0.900 secs
# Ready.
# Saved epoch 'proto3_stim_sw10035_E188.set' to epoch-data/proto3_stim_sw10035_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=107
#     Range : 0 ... 106 =      0.000 ...     1.060 secs
# Ready.
# Saved epoch 'proto3_stim_sw10037_E188.set' to epoch-data/proto3_stim_sw10037_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=94
#     Range : 0 ... 93 =      0.000 ...     0.930 secs
# Ready.
# Saved epoch 'proto3_stim_sw10038_E188.set' to epoch-data/proto3_stim_sw10038_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=114
#     Range : 0 ... 113 =      0.000 ...     1.130 secs
# Ready.
# Saved epoch 'proto3_stim_sw10039_E188.set' to epoch-data/proto3_stim_sw10039_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=101
#     Range : 0 ... 100 =      0.000 ...     1.000 secs
# Ready.
# Saved epoch 'proto3_stim_sw10040_E188.set' to epoch-data/proto3_stim_sw10040_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=76
#     Range : 0 ... 75 =      0.000 ...     0.750 secs
# Ready.
# Saved epoch 'proto3_stim_sw10041_E188.set' to epoch-data/proto3_stim_sw10041_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=95
#     Range : 0 ... 94 =      0.000 ...     0.940 secs
# Ready.
# Saved epoch 'proto3_stim_sw10042_E188.set' to epoch-data/proto3_stim_sw10042_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=107
#     Range : 0 ... 106 =      0.000 ...     1.060 secs
# Ready.
# Saved epoch 'proto3_stim_sw10043_E188.set' to epoch-data/proto3_stim_sw10043_E188.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw1_E2.set' to epoch-data/proto3_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=100
#     Range : 0 ... 99 =      0.000 ...     0.990 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw10_E2.set' to epoch-data/proto3_post-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=100
#     Range : 0 ... 99 =      0.000 ...     0.990 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw100_E2.set' to epoch-data/proto3_post-stim_sw100_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=93
#     Range : 0 ... 92 =      0.000 ...     0.920 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw1005_E16.set' to epoch-data/proto3_post-stim_sw1005_E16.set
# Creating RawArray with float64 data, n_channels=198, n_times=130
#     Range : 0 ... 129 =      0.000 ...     1.290 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw1006_E16.set' to epoch-data/proto3_post-stim_sw1006_E16.set
# Creating RawArray with float64 data, n_channels=198, n_times=110
#     Range : 0 ... 109 =      0.000 ...     1.090 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw1008_E16.set' to epoch-data/proto3_post-stim_sw1008_E16.set
# Creating RawArray with float64 data, n_channels=198, n_times=122
#     Range : 0 ... 121 =      0.000 ...     1.210 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw1009_E16.set' to epoch-data/proto3_post-stim_sw1009_E16.set
# Creating RawArray with float64 data, n_channels=198, n_times=126
#     Range : 0 ... 125 =      0.000 ...     1.250 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw10097_E177.set' to epoch-data/proto3_post-stim_sw10097_E177.set
# Creating RawArray with float64 data, n_channels=198, n_times=71
#     Range : 0 ... 70 =      0.000 ...     0.700 secs
# Ready.
# Saved epoch 'proto3_post-stim_sw10098_E177.set' to epoch-data/proto3_post-stim_sw10098_E177.set
# Creating RawArray with float64 data, n_channels=198, n_times=93
#     Range : 0 ... 92 =      0.000 ...     0.920 secs
# Ready.
# Saved epoch 'proto4_pre-stim_sw1_E2.set' to epoch-data/proto4_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=83
#     Range : 0 ... 82 =      0.000 ...     0.820 secs
# Ready.
# Saved epoch 'proto4_pre-stim_sw10_E2.set' to epoch-data/proto4_pre-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=73
#     Range : 0 ... 72 =      0.000 ...     0.720 secs
# Ready.
# Saved epoch 'proto4_pre-stim_sw100_E4.set' to epoch-data/proto4_pre-stim_sw100_E4.set
# Creating RawArray with float64 data, n_channels=198, n_times=80
#     Range : 0 ... 79 =      0.000 ...     0.790 secs
# Ready.
# Saved epoch 'proto4_pre-stim_sw1000_E46.set' to epoch-data/proto4_pre-stim_sw1000_E46.set
# Creating RawArray with float64 data, n_channels=198, n_times=181
#     Range : 0 ... 180 =      0.000 ...     1.800 secs
# Ready.
# Saved epoch 'proto4_pre-stim_sw1001_E46.set' to epoch-data/proto4_pre-stim_sw1001_E46.set
# Creating RawArray with float64 data, n_channels=198, n_times=153
#     Range : 0 ... 152 =      0.000 ...     1.520 secs
# Ready.
# Saved epoch 'proto4_pre-stim_sw1002_E46.set' to epoch-data/proto4_pre-stim_sw1002_E46.set
# Creating RawArray with float64 data, n_channels=198, n_times=118
#     Range : 0 ... 117 =      0.000 ...     1.170 secs
# Ready.
# Saved epoch 'proto4_pre-stim_sw1004_E46.set' to epoch-data/proto4_pre-stim_sw1004_E46.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto4_stim_sw1_E2.set' to epoch-data/proto4_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=139
#     Range : 0 ... 138 =      0.000 ...     1.380 secs
# Ready.
# Saved epoch 'proto4_stim_sw10_E2.set' to epoch-data/proto4_stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=75
#     Range : 0 ... 74 =      0.000 ...     0.740 secs
# Ready.
# Saved epoch 'proto4_stim_sw100_E3.set' to epoch-data/proto4_stim_sw100_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=146
#     Range : 0 ... 145 =      0.000 ...     1.450 secs
# Ready.
# Saved epoch 'proto4_stim_sw10000_E230.set' to epoch-data/proto4_stim_sw10000_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=138
#     Range : 0 ... 137 =      0.000 ...     1.370 secs
# Ready.
# Saved epoch 'proto4_stim_sw10001_E230.set' to epoch-data/proto4_stim_sw10001_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=105
#     Range : 0 ... 104 =      0.000 ...     1.040 secs
# Ready.
# Saved epoch 'proto4_stim_sw10002_E230.set' to epoch-data/proto4_stim_sw10002_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=125
#     Range : 0 ... 124 =      0.000 ...     1.240 secs
# Ready.
# Saved epoch 'proto4_stim_sw10004_E230.set' to epoch-data/proto4_stim_sw10004_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=85
#     Range : 0 ... 84 =      0.000 ...     0.840 secs
# Ready.
# Saved epoch 'proto4_stim_sw10005_E230.set' to epoch-data/proto4_stim_sw10005_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=148
#     Range : 0 ... 147 =      0.000 ...     1.470 secs
# Ready.
# Saved epoch 'proto4_stim_sw10007_E230.set' to epoch-data/proto4_stim_sw10007_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=123
#     Range : 0 ... 122 =      0.000 ...     1.220 secs
# Ready.
# Saved epoch 'proto4_stim_sw10008_E230.set' to epoch-data/proto4_stim_sw10008_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=98
#     Range : 0 ... 97 =      0.000 ...     0.970 secs
# Ready.
# Saved epoch 'proto4_stim_sw10010_E230.set' to epoch-data/proto4_stim_sw10010_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=80
#     Range : 0 ... 79 =      0.000 ...     0.790 secs
# Ready.
# Saved epoch 'proto4_stim_sw10012_E230.set' to epoch-data/proto4_stim_sw10012_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=90
#     Range : 0 ... 89 =      0.000 ...     0.890 secs
# Ready.
# Saved epoch 'proto4_stim_sw10014_E230.set' to epoch-data/proto4_stim_sw10014_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=142
#     Range : 0 ... 141 =      0.000 ...     1.410 secs
# Ready.
# Saved epoch 'proto4_stim_sw10015_E230.set' to epoch-data/proto4_stim_sw10015_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto4_stim_sw10016_E230.set' to epoch-data/proto4_stim_sw10016_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=137
#     Range : 0 ... 136 =      0.000 ...     1.360 secs
# Ready.
# Saved epoch 'proto4_stim_sw10017_E230.set' to epoch-data/proto4_stim_sw10017_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto4_stim_sw10019_E230.set' to epoch-data/proto4_stim_sw10019_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=147
#     Range : 0 ... 146 =      0.000 ...     1.460 secs
# Ready.
# Saved epoch 'proto4_stim_sw10021_E230.set' to epoch-data/proto4_stim_sw10021_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=106
#     Range : 0 ... 105 =      0.000 ...     1.050 secs
# Ready.
# Saved epoch 'proto4_stim_sw10022_E230.set' to epoch-data/proto4_stim_sw10022_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=81
#     Range : 0 ... 80 =      0.000 ...     0.800 secs
# Ready.
# Saved epoch 'proto4_stim_sw10024_E230.set' to epoch-data/proto4_stim_sw10024_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=80
#     Range : 0 ... 79 =      0.000 ...     0.790 secs
# Ready.
# Saved epoch 'proto4_stim_sw10025_E230.set' to epoch-data/proto4_stim_sw10025_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=98
#     Range : 0 ... 97 =      0.000 ...     0.970 secs
# Ready.
# Saved epoch 'proto4_stim_sw10027_E230.set' to epoch-data/proto4_stim_sw10027_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto4_stim_sw10029_E230.set' to epoch-data/proto4_stim_sw10029_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=70
#     Range : 0 ... 69 =      0.000 ...     0.690 secs
# Ready.
# Saved epoch 'proto4_stim_sw10031_E230.set' to epoch-data/proto4_stim_sw10031_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto4_stim_sw10033_E230.set' to epoch-data/proto4_stim_sw10033_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=112
#     Range : 0 ... 111 =      0.000 ...     1.110 secs
# Ready.
# Saved epoch 'proto4_stim_sw10035_E230.set' to epoch-data/proto4_stim_sw10035_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=131
#     Range : 0 ... 130 =      0.000 ...     1.300 secs
# Ready.
# Saved epoch 'proto4_stim_sw10036_E230.set' to epoch-data/proto4_stim_sw10036_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=83
#     Range : 0 ... 82 =      0.000 ...     0.820 secs
# Ready.
# Saved epoch 'proto4_stim_sw10038_E230.set' to epoch-data/proto4_stim_sw10038_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=101
#     Range : 0 ... 100 =      0.000 ...     1.000 secs
# Ready.
# Saved epoch 'proto4_stim_sw10039_E230.set' to epoch-data/proto4_stim_sw10039_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=109
#     Range : 0 ... 108 =      0.000 ...     1.080 secs
# Ready.
# Saved epoch 'proto4_stim_sw10040_E230.set' to epoch-data/proto4_stim_sw10040_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto4_stim_sw10041_E230.set' to epoch-data/proto4_stim_sw10041_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=79
#     Range : 0 ... 78 =      0.000 ...     0.780 secs
# Ready.
# Saved epoch 'proto4_stim_sw10043_E230.set' to epoch-data/proto4_stim_sw10043_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=140
#     Range : 0 ... 139 =      0.000 ...     1.390 secs
# Ready.
# Saved epoch 'proto4_stim_sw10045_E230.set' to epoch-data/proto4_stim_sw10045_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=123
#     Range : 0 ... 122 =      0.000 ...     1.220 secs
# Ready.
# Saved epoch 'proto4_stim_sw10046_E230.set' to epoch-data/proto4_stim_sw10046_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=143
#     Range : 0 ... 142 =      0.000 ...     1.420 secs
# Ready.
# Saved epoch 'proto4_stim_sw10047_E230.set' to epoch-data/proto4_stim_sw10047_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=130
#     Range : 0 ... 129 =      0.000 ...     1.290 secs
# Ready.
# Saved epoch 'proto4_stim_sw10048_E230.set' to epoch-data/proto4_stim_sw10048_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=142
#     Range : 0 ... 141 =      0.000 ...     1.410 secs
# Ready.
# Saved epoch 'proto4_stim_sw10049_E230.set' to epoch-data/proto4_stim_sw10049_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=78
#     Range : 0 ... 77 =      0.000 ...     0.770 secs
# Ready.
# Saved epoch 'proto4_stim_sw10050_E230.set' to epoch-data/proto4_stim_sw10050_E230.set
# Creating RawArray with float64 data, n_channels=198, n_times=111
#     Range : 0 ... 110 =      0.000 ...     1.100 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw1_E2.set' to epoch-data/proto4_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=103
#     Range : 0 ... 102 =      0.000 ...     1.020 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10_E2.set' to epoch-data/proto4_post-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=112
#     Range : 0 ... 111 =      0.000 ...     1.110 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw100_E3.set' to epoch-data/proto4_post-stim_sw100_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=148
#     Range : 0 ... 147 =      0.000 ...     1.470 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10000_E221.set' to epoch-data/proto4_post-stim_sw10000_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=153
#     Range : 0 ... 152 =      0.000 ...     1.520 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10001_E221.set' to epoch-data/proto4_post-stim_sw10001_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=182
#     Range : 0 ... 181 =      0.000 ...     1.810 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10002_E221.set' to epoch-data/proto4_post-stim_sw10002_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=97
#     Range : 0 ... 96 =      0.000 ...     0.960 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10004_E221.set' to epoch-data/proto4_post-stim_sw10004_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=146
#     Range : 0 ... 145 =      0.000 ...     1.450 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10005_E221.set' to epoch-data/proto4_post-stim_sw10005_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=115
#     Range : 0 ... 114 =      0.000 ...     1.140 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10006_E221.set' to epoch-data/proto4_post-stim_sw10006_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=98
#     Range : 0 ... 97 =      0.000 ...     0.970 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10007_E221.set' to epoch-data/proto4_post-stim_sw10007_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=160
#     Range : 0 ... 159 =      0.000 ...     1.590 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10008_E221.set' to epoch-data/proto4_post-stim_sw10008_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=112
#     Range : 0 ... 111 =      0.000 ...     1.110 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10010_E221.set' to epoch-data/proto4_post-stim_sw10010_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=139
#     Range : 0 ... 138 =      0.000 ...     1.380 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10011_E221.set' to epoch-data/proto4_post-stim_sw10011_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=159
#     Range : 0 ... 158 =      0.000 ...     1.580 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10013_E221.set' to epoch-data/proto4_post-stim_sw10013_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=81
#     Range : 0 ... 80 =      0.000 ...     0.800 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10015_E221.set' to epoch-data/proto4_post-stim_sw10015_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=96
#     Range : 0 ... 95 =      0.000 ...     0.950 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10016_E221.set' to epoch-data/proto4_post-stim_sw10016_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10018_E221.set' to epoch-data/proto4_post-stim_sw10018_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=107
#     Range : 0 ... 106 =      0.000 ...     1.060 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10020_E221.set' to epoch-data/proto4_post-stim_sw10020_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=136
#     Range : 0 ... 135 =      0.000 ...     1.350 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10021_E221.set' to epoch-data/proto4_post-stim_sw10021_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=115
#     Range : 0 ... 114 =      0.000 ...     1.140 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10022_E221.set' to epoch-data/proto4_post-stim_sw10022_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10023_E221.set' to epoch-data/proto4_post-stim_sw10023_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=80
#     Range : 0 ... 79 =      0.000 ...     0.790 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10024_E221.set' to epoch-data/proto4_post-stim_sw10024_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=94
#     Range : 0 ... 93 =      0.000 ...     0.930 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10025_E221.set' to epoch-data/proto4_post-stim_sw10025_E221.set
# Creating RawArray with float64 data, n_channels=198, n_times=130
#     Range : 0 ... 129 =      0.000 ...     1.290 secs
# Ready.
# Saved epoch 'proto4_post-stim_sw10170_E223.set' to epoch-data/proto4_post-stim_sw10170_E223.set
# Creating RawArray with float64 data, n_channels=198, n_times=74
#     Range : 0 ... 73 =      0.000 ...     0.730 secs
# Ready.
# Saved epoch 'proto5_pre-stim_sw1_E2.set' to epoch-data/proto5_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=86
#     Range : 0 ... 85 =      0.000 ...     0.850 secs
# Ready.
# Saved epoch 'proto5_pre-stim_sw10_E2.set' to epoch-data/proto5_pre-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=102
#     Range : 0 ... 101 =      0.000 ...     1.010 secs
# Ready.
# Saved epoch 'proto5_pre-stim_sw100_E3.set' to epoch-data/proto5_pre-stim_sw100_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=168
#     Range : 0 ... 167 =      0.000 ...     1.670 secs
# Ready.
# Saved epoch 'proto5_pre-stim_sw102_E3.set' to epoch-data/proto5_pre-stim_sw102_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=71
#     Range : 0 ... 70 =      0.000 ...     0.700 secs
# Ready.
# Saved epoch 'proto5_stim_sw1_E2.set' to epoch-data/proto5_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=77
#     Range : 0 ... 76 =      0.000 ...     0.760 secs
# Ready.
# Saved epoch 'proto5_stim_sw10_E2.set' to epoch-data/proto5_stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=85
#     Range : 0 ... 84 =      0.000 ...     0.840 secs
# Ready.
# Saved epoch 'proto5_stim_sw100_E11.set' to epoch-data/proto5_stim_sw100_E11.set
# Creating RawArray with float64 data, n_channels=198, n_times=135
#     Range : 0 ... 134 =      0.000 ...     1.340 secs
# Ready.
# Saved epoch 'proto5_stim_sw101_E11.set' to epoch-data/proto5_stim_sw101_E11.set
# Creating RawArray with float64 data, n_channels=198, n_times=94
#     Range : 0 ... 93 =      0.000 ...     0.930 secs
# Ready.
# Saved epoch 'proto5_stim_sw116_E14.set' to epoch-data/proto5_stim_sw116_E14.set
# Creating RawArray with float64 data, n_channels=198, n_times=78
#     Range : 0 ... 77 =      0.000 ...     0.770 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1_E2.set' to epoch-data/proto5_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=128
#     Range : 0 ... 127 =      0.000 ...     1.270 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw10_E2.set' to epoch-data/proto5_post-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1004_E138.set' to epoch-data/proto5_post-stim_sw1004_E138.set
# Creating RawArray with float64 data, n_channels=198, n_times=91
#     Range : 0 ... 90 =      0.000 ...     0.900 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1005_E138.set' to epoch-data/proto5_post-stim_sw1005_E138.set
# Creating RawArray with float64 data, n_channels=198, n_times=113
#     Range : 0 ... 112 =      0.000 ...     1.120 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1006_E138.set' to epoch-data/proto5_post-stim_sw1006_E138.set
# Creating RawArray with float64 data, n_channels=198, n_times=125
#     Range : 0 ... 124 =      0.000 ...     1.240 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1007_E138.set' to epoch-data/proto5_post-stim_sw1007_E138.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1008_E138.set' to epoch-data/proto5_post-stim_sw1008_E138.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1009_E138.set' to epoch-data/proto5_post-stim_sw1009_E138.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1051_E142.set' to epoch-data/proto5_post-stim_sw1051_E142.set
# Creating RawArray with float64 data, n_channels=198, n_times=138
#     Range : 0 ... 137 =      0.000 ...     1.370 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw1068_E145.set' to epoch-data/proto5_post-stim_sw1068_E145.set
# Creating RawArray with float64 data, n_channels=198, n_times=75
#     Range : 0 ... 74 =      0.000 ...     0.740 secs
# Ready.
# Saved epoch 'proto5_post-stim_sw143_E18.set' to epoch-data/proto5_post-stim_sw143_E18.set
# Creating RawArray with float64 data, n_channels=198, n_times=118
#     Range : 0 ... 117 =      0.000 ...     1.170 secs
# Ready.
# Saved epoch 'proto6_pre-stim_sw1_E2.set' to epoch-data/proto6_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=97
#     Range : 0 ... 96 =      0.000 ...     0.960 secs
# Ready.
# Saved epoch 'proto6_pre-stim_sw10_E25.set' to epoch-data/proto6_pre-stim_sw10_E25.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto6_stim_sw1_E2.set' to epoch-data/proto6_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=139
#     Range : 0 ... 138 =      0.000 ...     1.380 secs
# Ready.
# Saved epoch 'proto6_stim_sw100_E110.set' to epoch-data/proto6_stim_sw100_E110.set
# Creating RawArray with float64 data, n_channels=198, n_times=111
#     Range : 0 ... 110 =      0.000 ...     1.100 secs
# Ready.
# Saved epoch 'proto6_stim_sw101_E110.set' to epoch-data/proto6_stim_sw101_E110.set
# Creating RawArray with float64 data, n_channels=198, n_times=115
#     Range : 0 ... 114 =      0.000 ...     1.140 secs
# Ready.
# Saved epoch 'proto6_stim_sw16_E31.set' to epoch-data/proto6_stim_sw16_E31.set
# Creating RawArray with float64 data, n_channels=198, n_times=117
#     Range : 0 ... 116 =      0.000 ...     1.160 secs
# Ready.
# Saved epoch 'proto6_post-stim_sw1_E2.set' to epoch-data/proto6_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=140
#     Range : 0 ... 139 =      0.000 ...     1.390 secs
# Ready.
# Saved epoch 'proto6_post-stim_sw10_E25.set' to epoch-data/proto6_post-stim_sw10_E25.set
# Creating RawArray with float64 data, n_channels=198, n_times=138
#     Range : 0 ... 137 =      0.000 ...     1.370 secs
# Ready.
# Saved epoch 'proto6_post-stim_sw121_E136.set' to epoch-data/proto6_post-stim_sw121_E136.set
# Creating RawArray with float64 data, n_channels=198, n_times=109
#     Range : 0 ... 108 =      0.000 ...     1.080 secs
# Ready.
# Saved epoch 'proto7_pre-stim_sw1_E2.set' to epoch-data/proto7_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=89
#     Range : 0 ... 88 =      0.000 ...     0.880 secs
# Ready.
# Saved epoch 'proto7_pre-stim_sw10_E11.set' to epoch-data/proto7_pre-stim_sw10_E11.set
# Creating RawArray with float64 data, n_channels=198, n_times=103
#     Range : 0 ... 102 =      0.000 ...     1.020 secs
# Ready.
# Saved epoch 'proto7_pre-stim_sw110_E91.set' to epoch-data/proto7_pre-stim_sw110_E91.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto7_stim_sw1_E2.set' to epoch-data/proto7_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=133
#     Range : 0 ... 132 =      0.000 ...     1.320 secs
# Ready.
# ...
# Creating RawArray with float64 data, n_channels=198, n_times=132
#     Range : 0 ... 131 =      0.000 ...     1.310 secs
# Ready.
# Saved epoch 'proto8_post-stim_sw10500_E208.set' to epoch-data/proto8_post-stim_sw10500_E208.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto9_pre-stim_sw1_E2.set' to epoch-data/proto9_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=178
#     Range : 0 ... 177 =      0.000 ...     1.770 secs
# Ready.
# Saved epoch 'proto9_pre-stim_sw10_E2.set' to epoch-data/proto9_pre-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=92
#     Range : 0 ... 91 =      0.000 ...     0.910 secs
# Ready.
# Saved epoch 'proto9_pre-stim_sw100_E4.set' to epoch-data/proto9_pre-stim_sw100_E4.set
# Creating RawArray with float64 data, n_channels=198, n_times=112
#     Range : 0 ... 111 =      0.000 ...     1.110 secs
# Ready.
# Saved epoch 'proto9_pre-stim_sw1000_E57.set' to epoch-data/proto9_pre-stim_sw1000_E57.set
# Creating RawArray with float64 data, n_channels=198, n_times=88
#     Range : 0 ... 87 =      0.000 ...     0.870 secs
# Ready.
# Saved epoch 'proto9_pre-stim_sw1001_E57.set' to epoch-data/proto9_pre-stim_sw1001_E57.set
# Creating RawArray with float64 data, n_channels=198, n_times=137
#     Range : 0 ... 136 =      0.000 ...     1.360 secs
# Ready.
# Saved epoch 'proto9_pre-stim_sw1038_E61.set' to epoch-data/proto9_pre-stim_sw1038_E61.set
# Creating RawArray with float64 data, n_channels=198, n_times=123
#     Range : 0 ... 122 =      0.000 ...     1.220 secs
# Ready.
# Saved epoch 'proto9_pre-stim_sw359_E18.set' to epoch-data/proto9_pre-stim_sw359_E18.set
# Creating RawArray with float64 data, n_channels=198, n_times=127
#     Range : 0 ... 126 =      0.000 ...     1.260 secs
# Ready.
# Saved epoch 'proto9_stim_sw1_E2.set' to epoch-data/proto9_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=108
#     Range : 0 ... 107 =      0.000 ...     1.070 secs
# Ready.
# Saved epoch 'proto9_stim_sw10_E2.set' to epoch-data/proto9_stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=85
#     Range : 0 ... 84 =      0.000 ...     0.840 secs
# Ready.
# Saved epoch 'proto9_stim_sw100_E4.set' to epoch-data/proto9_stim_sw100_E4.set
# Creating RawArray with float64 data, n_channels=198, n_times=85
#     Range : 0 ... 84 =      0.000 ...     0.840 secs
# Ready.
# Saved epoch 'proto9_stim_sw1000_E57.set' to epoch-data/proto9_stim_sw1000_E57.set
# Creating RawArray with float64 data, n_channels=198, n_times=122
#     Range : 0 ... 121 =      0.000 ...     1.210 secs
# Ready.
# Saved epoch 'proto9_stim_sw1002_E57.set' to epoch-data/proto9_stim_sw1002_E57.set
# Creating RawArray with float64 data, n_channels=198, n_times=160
#     Range : 0 ... 159 =      0.000 ...     1.590 secs
# Ready.
# Saved epoch 'proto9_stim_sw1044_E61.set' to epoch-data/proto9_stim_sw1044_E61.set
# Creating RawArray with float64 data, n_channels=198, n_times=77
#     Range : 0 ... 76 =      0.000 ...     0.760 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw1_E2.set' to epoch-data/proto9_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=158
#     Range : 0 ... 157 =      0.000 ...     1.570 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10_E2.set' to epoch-data/proto9_post-stim_sw10_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=137
#     Range : 0 ... 136 =      0.000 ...     1.360 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw100_E3.set' to epoch-data/proto9_post-stim_sw100_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=142
#     Range : 0 ... 141 =      0.000 ...     1.410 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw1000_E27.set' to epoch-data/proto9_post-stim_sw1000_E27.set
# Creating RawArray with float64 data, n_channels=198, n_times=146
#     Range : 0 ... 145 =      0.000 ...     1.450 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw1001_E27.set' to epoch-data/proto9_post-stim_sw1001_E27.set
# Creating RawArray with float64 data, n_channels=198, n_times=139
#     Range : 0 ... 138 =      0.000 ...     1.380 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10016_E245.set' to epoch-data/proto9_post-stim_sw10016_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=101
#     Range : 0 ... 100 =      0.000 ...     1.000 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10017_E245.set' to epoch-data/proto9_post-stim_sw10017_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=170
#     Range : 0 ... 169 =      0.000 ...     1.690 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10019_E245.set' to epoch-data/proto9_post-stim_sw10019_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=126
#     Range : 0 ... 125 =      0.000 ...     1.250 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10020_E245.set' to epoch-data/proto9_post-stim_sw10020_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=174
#     Range : 0 ... 173 =      0.000 ...     1.730 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10022_E245.set' to epoch-data/proto9_post-stim_sw10022_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=123
#     Range : 0 ... 122 =      0.000 ...     1.220 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10023_E245.set' to epoch-data/proto9_post-stim_sw10023_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=125
#     Range : 0 ... 124 =      0.000 ...     1.240 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10024_E245.set' to epoch-data/proto9_post-stim_sw10024_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=85
#     Range : 0 ... 84 =      0.000 ...     0.840 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10025_E245.set' to epoch-data/proto9_post-stim_sw10025_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=74
#     Range : 0 ... 73 =      0.000 ...     0.730 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10026_E245.set' to epoch-data/proto9_post-stim_sw10026_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=165
#     Range : 0 ... 164 =      0.000 ...     1.640 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10028_E245.set' to epoch-data/proto9_post-stim_sw10028_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=100
#     Range : 0 ... 99 =      0.000 ...     0.990 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10029_E245.set' to epoch-data/proto9_post-stim_sw10029_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=114
#     Range : 0 ... 113 =      0.000 ...     1.130 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10030_E245.set' to epoch-data/proto9_post-stim_sw10030_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=126
#     Range : 0 ... 125 =      0.000 ...     1.250 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10031_E245.set' to epoch-data/proto9_post-stim_sw10031_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=110
#     Range : 0 ... 109 =      0.000 ...     1.090 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10032_E245.set' to epoch-data/proto9_post-stim_sw10032_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=105
#     Range : 0 ... 104 =      0.000 ...     1.040 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10033_E245.set' to epoch-data/proto9_post-stim_sw10033_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=94
#     Range : 0 ... 93 =      0.000 ...     0.930 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10034_E245.set' to epoch-data/proto9_post-stim_sw10034_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=122
#     Range : 0 ... 121 =      0.000 ...     1.210 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10035_E245.set' to epoch-data/proto9_post-stim_sw10035_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=174
#     Range : 0 ... 173 =      0.000 ...     1.730 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10036_E245.set' to epoch-data/proto9_post-stim_sw10036_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=143
#     Range : 0 ... 142 =      0.000 ...     1.420 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10037_E245.set' to epoch-data/proto9_post-stim_sw10037_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=131
#     Range : 0 ... 130 =      0.000 ...     1.300 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10039_E245.set' to epoch-data/proto9_post-stim_sw10039_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=115
#     Range : 0 ... 114 =      0.000 ...     1.140 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10041_E245.set' to epoch-data/proto9_post-stim_sw10041_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=151
#     Range : 0 ... 150 =      0.000 ...     1.500 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw10042_E245.set' to epoch-data/proto9_post-stim_sw10042_E245.set
# Creating RawArray with float64 data, n_channels=198, n_times=145
#     Range : 0 ... 144 =      0.000 ...     1.440 secs
# Ready.
# Saved epoch 'proto9_post-stim_sw1028_E27.set' to epoch-data/proto9_post-stim_sw1028_E27.set
# Creating RawArray with float64 data, n_channels=198, n_times=111
#     Range : 0 ... 110 =      0.000 ...     1.100 secs
# Ready.
# Saved epoch 'proto10_pre-stim_sw1_E2.set' to epoch-data/proto10_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=158
#     Range : 0 ... 157 =      0.000 ...     1.570 secs
# Ready.
# Saved epoch 'proto10_pre-stim_sw10_E3.set' to epoch-data/proto10_pre-stim_sw10_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=90
#     Range : 0 ... 89 =      0.000 ...     0.890 secs
# Ready.
# Saved epoch 'proto10_pre-stim_sw100_E18.set' to epoch-data/proto10_pre-stim_sw100_E18.set
# Creating RawArray with float64 data, n_channels=198, n_times=146
#     Range : 0 ... 145 =      0.000 ...     1.450 secs
# Ready.
# Saved epoch 'proto10_pre-stim_sw1000_E159.set' to epoch-data/proto10_pre-stim_sw1000_E159.set
# Creating RawArray with float64 data, n_channels=198, n_times=88
#     Range : 0 ... 87 =      0.000 ...     0.870 secs
# Ready.
# Saved epoch 'proto10_pre-stim_sw1012_E162.set' to epoch-data/proto10_pre-stim_sw1012_E162.set
# Creating RawArray with float64 data, n_channels=198, n_times=109
#     Range : 0 ... 108 =      0.000 ...     1.080 secs
# Ready.
# Saved epoch 'proto10_pre-stim_sw159_E27.set' to epoch-data/proto10_pre-stim_sw159_E27.set
# Creating RawArray with float64 data, n_channels=198, n_times=81
#     Range : 0 ... 80 =      0.000 ...     0.800 secs
# Ready.
# Saved epoch 'proto10_pre-stim_sw1662_E256.set' to epoch-data/proto10_pre-stim_sw1662_E256.set
# Creating RawArray with float64 data, n_channels=198, n_times=148
#     Range : 0 ... 147 =      0.000 ...     1.470 secs
# Ready.
# Saved epoch 'proto10_stim_sw1_E2.set' to epoch-data/proto10_stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=102
#     Range : 0 ... 101 =      0.000 ...     1.010 secs
# Ready.
# Saved epoch 'proto10_stim_sw10_E3.set' to epoch-data/proto10_stim_sw10_E3.set
# Creating RawArray with float64 data, n_channels=198, n_times=109
#     Range : 0 ... 108 =      0.000 ...     1.080 secs
# Ready.
# Saved epoch 'proto10_stim_sw1000_E187.set' to epoch-data/proto10_stim_sw1000_E187.set
# Creating RawArray with float64 data, n_channels=198, n_times=137
#     Range : 0 ... 136 =      0.000 ...     1.360 secs
# Ready.
# Saved epoch 'proto10_stim_sw1001_E187.set' to epoch-data/proto10_stim_sw1001_E187.set
# Creating RawArray with float64 data, n_channels=198, n_times=126
#     Range : 0 ... 125 =      0.000 ...     1.250 secs
# Ready.
# Saved epoch 'proto10_stim_sw1002_E187.set' to epoch-data/proto10_stim_sw1002_E187.set
# Creating RawArray with float64 data, n_channels=198, n_times=110
#     Range : 0 ... 109 =      0.000 ...     1.090 secs
# Ready.
# Saved epoch 'proto10_stim_sw1003_E187.set' to epoch-data/proto10_stim_sw1003_E187.set
# Creating RawArray with float64 data, n_channels=198, n_times=104
#     Range : 0 ... 103 =      0.000 ...     1.030 secs
# Ready.
# Saved epoch 'proto10_post-stim_sw1_E2.set' to epoch-data/proto10_post-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=141
#     Range : 0 ... 140 =      0.000 ...     1.400 secs
# Ready.
# Saved epoch 'proto10_post-stim_sw10_E5.set' to epoch-data/proto10_post-stim_sw10_E5.set
# Creating RawArray with float64 data, n_channels=198, n_times=93
#     Range : 0 ... 92 =      0.000 ...     0.920 secs
# Ready.
# Saved epoch 'proto10_post-stim_sw1005_E253.set' to epoch-data/proto10_post-stim_sw1005_E253.set
# Creating RawArray with float64 data, n_channels=198, n_times=87
#     Range : 0 ... 86 =      0.000 ...     0.860 secs
# Ready.
# Saved epoch 'proto10_post-stim_sw1006_E253.set' to epoch-data/proto10_post-stim_sw1006_E253.set
# Creating RawArray with float64 data, n_channels=198, n_times=160
#     Range : 0 ... 159 =      0.000 ...     1.590 secs
# Ready.
# Saved epoch 'proto10_post-stim_sw1007_E253.set' to epoch-data/proto10_post-stim_sw1007_E253.set
# Creating RawArray with float64 data, n_channels=198, n_times=117
#     Range : 0 ... 116 =      0.000 ...     1.160 secs
# Ready.
# Saved epoch 'proto10_post-stim_sw1016_E255.set' to epoch-data/proto10_post-stim_sw1016_E255.set
# Creating RawArray with float64 data, n_channels=198, n_times=125
#     Range : 0 ... 124 =      0.000 ...     1.240 secs
# Ready.
# Saved epoch 'proto10_post-stim_sw19_E11.set' to epoch-data/proto10_post-stim_sw19_E11.set
# Creating RawArray with float64 data, n_channels=198, n_times=172
#     Range : 0 ... 171 =      0.000 ...     1.710 secs
# Ready.
# Saved epoch 'proto11_pre-stim_sw1_E82.set' to epoch-data/proto11_pre-stim_sw1_E82.set
# Creating RawArray with float64 data, n_channels=198, n_times=185
#     Range : 0 ... 184 =      0.000 ...     1.840 secs
# Ready.
# Saved epoch 'proto12_pre-stim_sw1_E85.set' to epoch-data/proto12_pre-stim_sw1_E85.set
# Creating RawArray with float64 data, n_channels=198, n_times=169
#     Range : 0 ... 168 =      0.000 ...     1.680 secs
# Ready.
# Saved epoch 'proto12_stim_sw1_E37.set' to epoch-data/proto12_stim_sw1_E37.set
# Creating RawArray with float64 data, n_channels=198, n_times=106
#     Range : 0 ... 105 =      0.000 ...     1.050 secs
# Ready.
# Saved epoch 'proto12_post-stim_sw1_E237.set' to epoch-data/proto12_post-stim_sw1_E237.set
# Creating RawArray with float64 data, n_channels=198, n_times=176
#     Range : 0 ... 175 =      0.000 ...     1.750 secs
# Ready.
# Saved epoch 'proto13_post-stim_sw1_E119.set' to epoch-data/proto13_post-stim_sw1_E119.set
# Creating RawArray with float64 data, n_channels=198, n_times=77
#     Range : 0 ... 76 =      0.000 ...     0.760 secs
# Ready.
# Saved epoch 'proto14_pre-stim_sw1_E2.set' to epoch-data/proto14_pre-stim_sw1_E2.set
# Creating RawArray with float64 data, n_channels=198, n_times=81
#     Range : 0 ... 80 =      0.000 ...     0.800 secs
# Ready.
# Saved epoch 'proto14_pre-stim_sw11_E31.set' to epoch-data/proto14_pre-stim_sw11_E31.set
# Creating RawArray with float64 data, n_channels=198, n_times=156
#     Range : 0 ... 155 =      0.000 ...     1.550 secs
# Ready.
# Saved epoch 'proto14_stim_sw1_E18.set' to epoch-data/proto14_stim_sw1_E18.set
# Creating RawArray with float64 data, n_channels=198, n_times=182
#     Range : 0 ... 181 =      0.000 ...     1.810 secs
# Ready.
# Saved epoch 'proto15_stim_sw1_E18.set' to epoch-data/proto15_stim_sw1_E18.set
# Creating RawArray with float64 data, n_channels=198, n_times=167
#     Range : 0 ... 166 =      0.000 ...     1.660 secs
# Ready.
# Saved epoch 'proto16_post-stim_sw1_E14.set' to epoch-data/proto16_post-stim_sw1_E14.set
# Creating RawArray with float64 data, n_channels=198, n_times=160
#     Range : 0 ... 159 =      0.000 ...     1.590 secs
# Ready.
# Saved epoch 'proto18_stim_sw1_E237.set' to epoch-data/proto18_stim_sw1_E237.set
# Creating RawArray with float64 data, n_channels=198, n_times=156
#     Range : 0 ... 155 =      0.000 ...     1.550 secs
# Ready.
# Saved epoch 'proto18_post-stim_sw1_E11.set' to epoch-data/proto18_post-stim_sw1_E11.set
# All epochs have been successfully saved as .set files in the 'epoch-data' directory.

# %%
# Assuming df_actual is already loaded and contains the necessary data
# Load raw EEG data (if not already loaded)
raw = mne.io.read_raw_eeglab('annotated_raw.set', preload=True)
sf = raw.info['sfreq']

# Set the fixed waveform length in seconds
waveform_length = 1  # 2 seconds
n_samples = int(waveform_length * sf)  # Convert to samples

# Create a dictionary to store waveforms for each stim condition
waveforms_by_condition = {}

for stim_condition in df_actual['Classification'].unique():
    condition_data = df_actual[df_actual['Classification'] == stim_condition]
    waveforms = []
    for _, row in condition_data.iterrows():
        # Extract start sample
        start_sample = int(row['Start'] * sf)
        end_sample = start_sample + n_samples  # Ensure fixed length of 2 seconds

        # Validate that the end_sample doesn't exceed the data limits
        if end_sample > raw.n_times:
            continue  # Skip this waveform if it goes beyond the data length

        # Extract the waveform for the specific channel
        channel_idx = raw.ch_names.index(row['Channel'])
        waveform = raw.get_data(picks=[channel_idx], start=start_sample, stop=end_sample).flatten()

        # Convert waveform from V to uV
        waveform_uV = waveform * 1e6  # Conversion from V to uV

        # Center the waveform relative to its start
        waveform_centered = waveform_uV - waveform_uV[0]
        waveforms.append(waveform_centered)

    waveforms_by_condition[stim_condition] = np.array(waveforms)

# Plot the averages
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
time = np.linspace(0, waveform_length, n_samples)  # Time vector

colors = {'pre-stim': 'blue', 'stim': 'orange', 'post-stim': 'green'}
for stim_condition, waveforms in waveforms_by_condition.items():
    if waveforms.size > 0:
        avg_waveform = waveforms.mean(axis=0)
        std_waveform = waveforms.std(axis=0)
        plt.plot(time, avg_waveform, label=f'{stim_condition.capitalize()} (n={waveforms.shape[0]})', color=colors[stim_condition])
        plt.fill_between(time, avg_waveform - std_waveform, avg_waveform + std_waveform, alpha=0.2, color=colors[stim_condition])

plt.axvline(0, color='black', linestyle='--', label='Start')
plt.title('Average Waveforms Per Stimulation Condition (Centered at Start)')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (uV)')  # Corrected unit label
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
